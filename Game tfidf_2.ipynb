# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
game_reviews = pd.read_csv("all_Steam_Reviews_cleaned_1.csv")
pos_reviews=pd.read_csv("positive_steam_reviews_1.csv")
neg_reviews=pd.read_csv("negative_steam_reviews_1.csv")

# %%
pos_reviews
# Out:
#                       game                                             review  \
# 0      Company of Heroes 3  Here is my actual review. COH3 has the best Qo...
# 1      Company of Heroes 3  I resisted for quite a while to buy this game ...
# 2      Company of Heroes 3  Final Thoughts\nCompany of Heroes 3 is a stunn...
# 3      Company of Heroes 3  game has come a long way since release but can...
# 4      Company of Heroes 3  A great RTS that is going to get better with e...
# ...                    ...                                                ...
# 34040      Baldur's Gate 3  It's not just a game! It's a whole story that ...
# 34041      Baldur's Gate 3  It's the closest you're going to get to playin...
# 34042      Baldur's Gate 3  verry gooood gammeeee. I slept on it for to lo...
# 34043      Baldur's Gate 3  Funny wild magic sorceror Durge run made every...
# 34044      Baldur's Gate 3  this game is amazing and a blast to play. ever...
#
#        recommended                     genre  action  strategy  free_to_play  \
# 0             True          Action, Strategy    True      True         False
# 1             True          Action, Strategy    True      True         False
# 2             True          Action, Strategy    True      True         False
# 3             True          Action, Strategy    True      True         False
# 4             True          Action, Strategy    True      True         False
# ...            ...                       ...     ...       ...           ...
# 34040         True  Adventure, RPG, Strategy   False      True         False
# 34041         True  Adventure, RPG, Strategy   False      True         False
# 34042         True  Adventure, RPG, Strategy   False      True         False
# 34043         True  Adventure, RPG, Strategy   False      True         False
# 34044         True  Adventure, RPG, Strategy   False      True         False
#
#        adventure  massively_multiplayer  indie  ...  casual  racing  \
# 0          False                  False  False  ...   False   False
# 1          False                  False  False  ...   False   False
# 2          False                  False  False  ...   False   False
# 3          False                  False  False  ...   False   False
# 4          False                  False  False  ...   False   False
# ...          ...                    ...    ...  ...     ...     ...
# 34040       True                  False  False  ...   False   False
# 34041       True                  False  False  ...   False   False
# 34042       True                  False  False  ...   False   False
# 34043       True                  False  False  ...   False   False
# 34044       True                  False  False  ...   False   False
#
#        early_access  simulation  unknown_genre  sports  violent  education  \
# 0             False       False          False   False    False      False
# 1             False       False          False   False    False      False
# 2             False       False          False   False    False      False
# 3             False       False          False   False    False      False
# 4             False       False          False   False    False      False
# ...             ...         ...            ...     ...      ...        ...
# 34040         False       False          False   False    False      False
# 34041         False       False          False   False    False      False
# 34042         False       False          False   False    False      False
# 34043         False       False          False   False    False      False
# 34044         False       False          False   False    False      False
#
#        utilities                                     cleaned_review
# 0          False  actual review good qol franchise stop play fav...
# 1          False  resist buy game not expect game different fina...
# 2          False  final thought company heroe stunning evolution...
# 3          False  game come long way release feel like cash grab...
# 4          False  great rt go well major update time start play ...
# ...          ...                                                ...
# 34040      False  game story completely immerse primarily thank ...
# 34041      False  close go play dnd group friend willing sit pla...
# 34042      False  verry gooood gammeeee sleep long finish ton co...
# 34043      False  funny wild magic sorceror durge run turn cat t...
# 34044      False               game amazing blast play run diffrent
#
# [34045 rows x 21 columns]

# %%
#avoid error later
pos_reviews.rename(columns={'game': 'Game'}, inplace=True)
neg_reviews.rename(columns={'game': 'Game'}, inplace=True)
game_reviews.rename(columns={'game': 'Game'}, inplace=True)

# %%
game_reviews.columns
# Out:
# Index(['Game', 'review', 'recommended', 'genre', 'action', 'strategy',
#        'free_to_play', 'adventure', 'massively_multiplayer', 'indie', 'rpg',
#        'casual', 'racing', 'early_access', 'simulation', 'unknown_genre',
#        'sports', 'violent', 'education', 'utilities', 'cleaned_review'],
#       dtype='object')

# %%
# Define TF-IDF vectorizers
vectorizer_pos = TfidfVectorizer(stop_words="english", ngram_range=(1,2), max_features=5000)  # Unigrams & bigrams
vectorizer_neg = TfidfVectorizer(stop_words="english", ngram_range=(1,2), max_features=5000)  # Unigrams & bigrams

# Remove NaN values from the cleaned_review columns
pos_reviews_cleaned = pos_reviews["cleaned_review"].dropna()
neg_reviews_cleaned = neg_reviews["cleaned_review"].dropna()

# Fit and transform the positive reviews
tfidf_matrix_pos = vectorizer_pos.fit_transform(pos_reviews_cleaned)

# Fit and transform the negative reviews
tfidf_matrix_neg = vectorizer_neg.fit_transform(neg_reviews_cleaned)

# Get feature names
terms_pos = vectorizer_pos.get_feature_names_out()
terms_neg = vectorizer_neg.get_feature_names_out()

# Compute the mean TF-IDF scores per term
tfidf_sum_pos = tfidf_matrix_pos.mean(axis=0).A1
tfidf_sum_neg = tfidf_matrix_neg.mean(axis=0).A1

# Create DataFrames with terms and scores
tfidf_df_pos = pd.DataFrame({'term': terms_pos, 'tfidf_score': tfidf_sum_pos})
tfidf_df_neg = pd.DataFrame({'term': terms_neg, 'tfidf_score': tfidf_sum_neg})

# Sort by importance (highest TF-IDF scores)
tfidf_df_pos = tfidf_df_pos.sort_values(by="tfidf_score", ascending=False)
tfidf_df_neg = tfidf_df_neg.sort_values(by="tfidf_score", ascending=False)

# %%
# Define function to get top words per game
def get_top_words_per_game(reviews_df, vectorizer, top_n=10):
    top_words_per_game = {}

    for game in reviews_df["Game"].unique():
        # Filter reviews for the specific game
        game_reviews = reviews_df[reviews_df["Game"] == game]["cleaned_review"]

        if game_reviews.empty:
            continue  # Skip if no reviews

        # Apply TF-IDF for the specific game
        tfidf_matrix = vectorizer.fit_transform(game_reviews)
        terms = vectorizer.get_feature_names_out()

        # Compute mean TF-IDF scores for words
        row = tfidf_matrix.mean(axis=0).A1
        sorted_terms = [terms[idx] for idx in row.argsort()[::-1][:top_n]]

        # Store in dictionary
        top_words_per_game[game] = sorted_terms

    return top_words_per_game

# %%
# Remove NaN values from the cleaned_review columns
pos_reviews_cleaned = pos_reviews.dropna(subset=['cleaned_review'])
neg_reviews_cleaned = neg_reviews.dropna(subset=['cleaned_review'])

# Compute top words per game for positive & negative reviews
top_words_pos = get_top_words_per_game(pos_reviews_cleaned, vectorizer_pos)
top_words_neg = get_top_words_per_game(neg_reviews_cleaned, vectorizer_neg)

# %%
# Ensure both dictionaries have the same keys
games = set(top_words_pos.keys()).union(set(top_words_neg.keys()))

# Create lists for DataFrame
games_list = []
top_pos_words_list = []
top_neg_words_list = []

for game in games:
    games_list.append(game)
    top_pos_words_list.append(top_words_pos.get(game, []))
    top_neg_words_list.append(top_words_neg.get(game, []))

# Convert to DataFrame
df_top_words = pd.DataFrame({
    "Game": games_list,
    "Top_Positive_Words": top_pos_words_list,
    "Top_Negative_Words": top_neg_words_list
})

# Save to CSV
df_top_words.to_csv("game_top_tfidf_words.csv", index=False)

# %%
df_top_words
# Out:
#                   Game                                 Top_Positive_Words  \
# 0            Fallout 4  [game, good, fallout, fun, mod, play, great, s...
# 1         Phasmophobia  [game, fun, play, friend, ghost, good, scary, ...
# 2       Battlefield 4™  [good, game, battlefield, good game, yes, grea...
# 3             Terraria  [game, fun, play, good, great, like, good game...
# 4       Cursed to Golf  [game, amazing, game amazing, golf, hole, card...
# ..                 ...                                                ...
# 92  Deep Rock Galactic  [game, rock, stone, fun, rock stone, good, pla...
# 93      Planet Coaster  [game, good, fun, coaster, great, park, like, ...
# 94    X-Morph: Defense  [game, good, tower, good game, great game, gre...
# 95   Shadowrun Returns  [game, bad, good, shadowrun, story, play, nice...
# 96        Atomic Heart  [game, good, good game, fun, great, story, pla...
#
#                                    Top_Negative_Words
# 0   [game, play, mod, crash, time, update, fallout...
# 1   [game, like, update, play, new, fix, work, gho...
# 2   [game, punkbuster, server, play, kick, bug, mu...
# 3   [que, crringe jk, boss ranaway, leave, leave c...
# 4   [game, stroke, card, weird, tutorial, golf, fe...
# ..                                                ...
# 92  [game, mod, good, like, play, feel, player, ho...
# 93  [game, buit, worth, coaster, build, buy, good,...
# 94  [screen, look, good boring, look good, quickly...
# 95  [sequel, miss, game, buggy, think, definitely ...
# 96  [game, good, like, hour, play, difficult, feel...
#
# [97 rows x 3 columns]

# %% [markdown]
# As we can see the words have some like "game", "good", "play", "great", "bad" that doesnt really say nothing to us, therefore we have to add them to a stopword list to remove them.

# %%
# Custom stopwords to remove
custom_stopwords = {"ve", "re", "want", "try", "new", "work", "need", "thing", "buy", "fix", 
    "hour", "long", "gameplay", "update", "dlc", "player", "pay",
    'time', 'game', 'play', 'good', 'great', 'bad', 'like', 'fun', 
    'best', 'better', 'enjoy', 'recommend', 'yes', "feel", "lot", "come", "way", "nice", "ha", "think",
    "aight", "haha", "gobagool", "goate", "unsuur", "jyjtyjtukutk"
}


def remove_custom_stopwords(text):
    # Tokenize the text using whitespace and remove custom stopwords (ignoring case)
    tokens = text.split()
    filtered_tokens = [token for token in tokens if token.lower() not in custom_stopwords]
    return ' '.join(filtered_tokens)

# Remove NaN values and then apply the custom stopwords removal for positive reviews
pos_reviews_cleaned = pos_reviews.dropna(subset=['cleaned_review'])
pos_reviews_cleaned["cleaned_review"] = pos_reviews_cleaned["cleaned_review"].apply(remove_custom_stopwords)

# Remove NaN values and apply custom stopwords removal for negative reviews
neg_reviews_cleaned = neg_reviews.dropna(subset=['cleaned_review'])
neg_reviews_cleaned["cleaned_review"] = neg_reviews_cleaned["cleaned_review"].apply(remove_custom_stopwords)

# Define TF-IDF vectorizers
vectorizer_pos = TfidfVectorizer(stop_words="english", ngram_range=(1,2), max_features=5000)  # Unigrams & bigrams for positive reviews
vectorizer_neg = TfidfVectorizer(stop_words="english", ngram_range=(1,2), max_features=5000)  # Unigrams & bigrams for negative reviews

# Fit and transform the positive reviews
tfidf_matrix_pos = vectorizer_pos.fit_transform(pos_reviews_cleaned["cleaned_review"])

# Fit and transform the negative reviews
tfidf_matrix_neg = vectorizer_neg.fit_transform(neg_reviews_cleaned["cleaned_review"])

# Get feature names
terms_pos = vectorizer_pos.get_feature_names_out()
terms_neg = vectorizer_neg.get_feature_names_out()

# Compute the mean TF-IDF scores per term
tfidf_sum_pos = tfidf_matrix_pos.mean(axis=0).A1 #avoid being biased towards longer documents (that's why we don't use the sum as in class)
tfidf_sum_neg = tfidf_matrix_neg.mean(axis=0).A1

# Create DataFrames with terms and scores
tfidf_df_pos = pd.DataFrame({'term': terms_pos, 'tfidf_score': tfidf_sum_pos})
tfidf_df_neg = pd.DataFrame({'term': terms_neg, 'tfidf_score': tfidf_sum_neg})

# Sort by importance (highest TF-IDF scores)
tfidf_df_pos = tfidf_df_pos.sort_values(by="tfidf_score", ascending=False)
tfidf_df_neg = tfidf_df_neg.sort_values(by="tfidf_score", ascending=False)

# Define function to get top words per game
def get_top_words_per_game(reviews_df, vectorizer, top_n=10):
    top_words_per_game = {}
    for game in reviews_df["Game"].unique():
        # Filter reviews for the specific game
        game_reviews = reviews_df[reviews_df["Game"] == game]["cleaned_review"]
        if game_reviews.empty:
            continue  # Skip if no reviews
        # Apply TF-IDF for the specific game
        tfidf_matrix = vectorizer.fit_transform(game_reviews)
        terms = vectorizer.get_feature_names_out()
        # Compute mean TF-IDF scores for words
        row = tfidf_matrix.mean(axis=0).A1
        sorted_terms = [terms[idx] for idx in row.argsort()[::-1][:top_n]]
        # Store in dictionary
        top_words_per_game[game] = sorted_terms
    return top_words_per_game

# Compute top words per game for positive & negative reviews
top_words_pos = get_top_words_per_game(pos_reviews_cleaned, vectorizer_pos)
top_words_neg = get_top_words_per_game(neg_reviews_cleaned, vectorizer_neg)

# Ensure both dictionaries have the same keys
games = set(top_words_pos.keys()).union(set(top_words_neg.keys()))

# Create lists for DataFrame
games_list = []
top_pos_words_list = []
top_neg_words_list = []

for game in games:
    games_list.append(game)
    top_pos_words_list.append(top_words_pos.get(game, []))
    top_neg_words_list.append(top_words_neg.get(game, []))

# Convert to DataFrame
df_top_words = pd.DataFrame({
    "Game": games_list,
    "Top_Positive_Words": top_pos_words_list,
    "Top_Negative_Words": top_neg_words_list
})

# Save to CSV
df_top_words.to_csv("game_top_tfidf_words.csv", index=False)
# Out:
# /tmp/ipykernel_37359/2753569525.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pos_reviews_cleaned["cleaned_review"] = pos_reviews_cleaned["cleaned_review"].apply(remove_custom_stopwords)
# /tmp/ipykernel_37359/2753569525.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   neg_reviews_cleaned["cleaned_review"] = neg_reviews_cleaned["cleaned_review"].apply(remove_custom_stopwords)

# %%
df_top_words
# Out:
#                   Game                                 Top_Positive_Words  \
# 0            Fallout 4  [fallout, mod, story, love, world, amazing, be...
# 1         Phasmophobia  [friend, scary, ghost, love, horror, solo, sca...
# 2       Battlefield 4™  [battlefield, campaign, love, story, server, g...
# 3             Terraria  [friend, mod, minecraft, boss, terraria, amazi...
# 4       Cursed to Golf  [amazing, golf, worth price, worth, price, hol...
# ..                 ...                                                ...
# 92  Deep Rock Galactic  [rock, stone, rock stone, friend, bug, coop, d...
# 93      Planet Coaster  [coaster, park, love, amazing, awesome, planet...
# 94    X-Morph: Defense  [tower, defense, tower defense, strategy, pret...
# 95   Shadowrun Returns  [shadowrun, story, worth, pretty, look, rpg, j...
# 96        Atomic Heart  [story, love, interesting, bioshock, robot, co...
#
#                                    Top_Negative_Words
# 0   [mod, crash, fallout, load, bethesda, bug, pat...
# 1   [ghost, lobby, map, rework, community, release...
# 2   [punkbuster, server, kick, bug, multiplayer, e...
# 3   [que, crringe, boss, leave, leave crringe, crr...
# 4   [stroke, card, weird, tutorial, golf, use, suf...
# ..                                                ...
# 92  [mod, friend, focus, upgrade, experience, stuc...
# 93  [buit, worth, cool, cool ride, ride, coaster, ...
# 94  [screen, look, look boring, boring, boring qui...
# 95  [sequel, miss, okay, forgettable ending, trilo...
# 96  [weird, difficult, robot, story, bug, characte...
#
# [97 rows x 3 columns]

# %%
for index, row in df_top_words.iterrows():
    print(f"{row['Game']} - Positive Words: {row['Top_Positive_Words']}")
# Out:
# Fallout 4 - Positive Words: ['fallout', 'mod', 'story', 'love', 'world', 'amazing', 'bethesda', 'settlement', 'year', 'open']
# Phasmophobia - Positive Words: ['friend', 'scary', 'ghost', 'love', 'horror', 'solo', 'scare', 'map', 'people', 'hard']
# Battlefield 4™ - Positive Words: ['battlefield', 'campaign', 'love', 'story', 'server', 'gud', 'peak', 'multiplayer', 'amazing', 'ok']
# Terraria - Positive Words: ['friend', 'mod', 'minecraft', 'boss', 'terraria', 'amazing', 'love', 'build', 'cool', 'hard']
# Cursed to Golf - Positive Words: ['amazing', 'golf', 'worth price', 'worth', 'price', 'hole', 'card', 'pretty', 'level', 'add']
# Satisfactory - Positive Words: ['factory', 'love', 'build', 'friend', 'amazing', 'building', 'world', 'satisfactory', 'start', 'explore']
# DARK SOULS™ II - Positive Words: ['soul', 'dark', 'dark soul', 'peak soul', 'hard', 'peak', 'realize', 'version', 'scholar', 'tbh']
# Counter-Strike 2 - Positive Words: ['cheater', 'love', 'friend', 'valve', 'russian', 'csgo', 'cheat', 'hard', 'make', 'team']
# Monster Hunter: World - Positive Words: ['monster', 'hunter', 'monster hunter', 'wild', 'friend', 'love', 'world', 'weapon', 'hunt', 'pc']
# Windblown - Positive Words: ['friend', 'dead', 'dead cell', 'cell', 'early', 'content', 'look', 'early access', 'access', 'wait']
# Dota 2 - Positive Words: ['love', 'free', 'dangerous', 'killer dangerous', 'killer', 'heed caution', 'heed', 'caution start', 'caution', 'start']
# My Time at Sandrock - Positive Words: ['love', 'story', 'character', 'portia', 'sandrock', 'addict', 'fantastic', 'wait', 'couple', 'highly']
# Titanfall® 2 - Positive Words: ['campaign', 'story', 'multiplayer', 'amazing', 'titanfall', 'movement', 'fps', 'shooter', 'love', 'titan']
# 100% Orange Juice - Positive Words: ['friend', 'party', 'juice', 'mario party', 'mario', 'cute', 'roll', 'gamble', 'anime', 'orange']
# Pathfinder: Kingmaker — Enhanced Plus Edition - Positive Words: ['pathfinder', 'story', 'character', 'rpg', 'dd', 'crpgs', 'engage', 'save', 'love', 'gate']
# Keep Driving - Positive Words: ['music', 'love', 'amazing', 'drive', 'road', 'soundtrack', 'run', 'art', 'vibe', 'trip']
# Valheim - Positive Words: ['friend', 'survival', 'build', 'world', 'love', 'building', 'valheim', 'craft', 'explore', 'boss']
# PUBG: BATTLEGROUNDS - Positive Words: ['pubg', 'br', 'love', 'gud', 'friend', 'shoot', 'cool', 'ok', 'awesome', 'year']
# ARK: Survival Ascended - Positive Words: ['ark', 'love', 'graphic', 'mod', 'server', 'friend', 'issue', 'bug', 'pc', 'crash']
# Sid Meier’s Civilization® VI - Positive Words: ['civ', 'strategy', 'love', 'turn', 'civilization', 'friend', 'vi', 'civ civ', 'mod', 'vii']
# DiRT Rally - Positive Words: ['rally', 'old', 'drive', 'dirt', 'dirt rally', 'car', 'suck', 'ultimate rally', 'ultimate', 'hard']
# Crusader Kings III - Positive Words: ['incest', 'mod', 'strategy', 'spend', 'legit', 'ok', 'refreshment', 'addiction', 'king', 'historical']
# MONSTER HUNTER RISE - Positive Words: ['monster', 'world', 'hunter', 'monster hunter', 'wild', 'mh', 'rise', 'peak', 'ok', 'switch']
# Baldur's Gate 3 - Positive Words: ['story', 'amazing', 'character', 'love', 'dnd', 'rpg', 'different', 'combat', 'act', 'dd']
# Yakuza 0 - Positive Words: ['peak', 'yakuza', 'story', 'majima', 'love', 'series', 'absolute', 'amazing', 'kiryu', 'awesome']
# CODE VEIN - Positive Words: ['soul', 'anime', 'story', 'code', 'dark', 'vein', 'code vein', 'expect', 'io', 'dark soul']
# Dead by Daylight - Positive Words: ['killer', 'friend', 'love', 'survivor', 'horror', 'people', 'toxic', 'community', 'hate', 'killer survivor']
# The Witcher 3: Wild Hunt - Positive Words: ['story', 'world', 'witcher', 'amazing', 'quest', 'graphic', 'combat', 'character', 'love', 'year']
# Exanima - Positive Words: ['combat', 'difficult', 'phillip', 'access', 'early', 'early access', 'arena', 'worth', 'year', 'learn']
# Brawlhalla - Positive Words: ['ah', 'quit', 'ah fight', 'goofy ah', 'diamond', 'diamond quit', 'fight', 'goofy', 'playing', 'quit playing']
# Destiny 2 - Positive Words: ['life', 'destiny', 'love', 'content', 'amazing', 'guess', 'pretty', 'friend', 'story', 'hate']
# Beast Saga - Positive Words: ['rpgea']
# Rust - Positive Words: ['rust', 'server', 'friend', 'love', 'base', 'survival', 'raid', 'kill', 'amazing', 'hard']
# FragPunk - Positive Words: ['free', 'card', 'shooter', 'currency', 'beta', 'movement', 'love', 'people', 'valorant', 'character']
# Team Fortress 2 - Positive Words: ['team', 'spy', 'love', 'fortress', 'shit', 'heavy', 'team fortress', 'funny', 'cool', 'medic']
# Black Squad - Positive Words: ['beste', 'sehr', 'beste anticheat', 'clan', 'legende', 'legende clan', 'anticheat', 'anticheat legende', 'beste beste', 'easy']
# ARK: Survival Evolved - Positive Words: ['mod', 'dinosaur', 'survival', 'friend', 'ark', 'dino', 'die', 'love', 'amazing', 'tame']
# Euro Truck Simulator 2 - Positive Words: ['truck', 'drive', 'relax', 'love', 'realistic', 'simulator', 'wheel', 'graphic', 'friend', 'mod']
# Grand Theft Auto V Legacy - Positive Words: ['story', 'online', 'gta', 'mode', 'friend', 'story mode', 'graphic', 'love', 'mission', 'car']
# Age of Empires IV: Anniversary Edition - Positive Words: ['rt', 'love', 'strategy', 'age', 'aoe', 'amazing', 'empire', 'age empire', 'highly', 'different']
# Contra Anniversary Collection - Positive Words: ['contra', 'collection', 'right', 'nostalgia', 'konami', 'hard', 'grow contra', 'contra right', 'right anytime', 'anytime']
# Marvel’s Spider-Man Remastered - Positive Words: ['spiderman', 'story', 'love', 'amazing', 'man', 'cool', 'spider', 'combat', 'spider man', 'make']
# BONEWORKS - Positive Words: ['bone', 'vr', 'story', 'bonelab', 'amazing', 'bonework', 'cool', 'sandbox', 'mod', 'love']
# The Binding of Isaac: Rebirth - Positive Words: ['isaac', 'mod', 'item', 'run', 'love', 'hard', 'roguelike', 'dlcs', 'bind', 'god']
# Barotrauma - Positive Words: ['friend', 'submarine', 'barotrauma', 'cool', 'scary', 'peak', 'yep', 'ship', 'amazing', 'love']
# Cyberpunk 2077 - Positive Words: ['story', 'amazing', 'character', 'cyberpunk', 'graphic', 'bug', 'world', 'release', 'love', 'experience']
# Dying Light - Positive Words: ['zombie', 'story', 'parkour', 'love', 'die', 'light', 'die light', 'friend', 'amazing', 'year']
# Darkest Dungeon® II - Positive Words: ['kingdom', 'dungeon', 'different', 'dark', 'mode', 'amazing', 'love', 'dark dungeon', 'run', 'character']
# Mass Effect™ Legendary Edition - Positive Words: ['story', 'mass', 'effect', 'mass effect', 'trilogy', 'love', 'series', 'favorite', 'amazing', 'character']
# 0 Day - Positive Words: ['wait devs', 'wait', 'love wait', 'love', 'devs']
# Golf With Your Friends - Positive Words: ['friend', 'golf', 'golf friend', 'ball', 'hate', 'hole', 'map', 'lose', 'love', 'hit']
# Cookie Clicker - Positive Words: ['cookie', 'click', 'click cookie', 'cookie cookie', 'clicker', 'cookie clicker', 'worth', 'achievement', 'simple', 'life']
# Beat Saber - Positive Words: ['vr', 'beat', 'mod', 'saber', 'beat saber', 'exercise', 'love', 'song', 'gud', 'block']
# Tower Unite - Positive Words: ['friend', 'tower', 'make', 'loooooove', 'gamba', 'buggy', 'love', 'gambling', 'golf', 'social']
# Lossless Scaling - Positive Words: ['fps', 'frame', 'software', 'generation', 'use', 'frame generation', 'old', 'amazing', 'scale', 'gpu']
# Robin Hood - Sherwood Builders - Positive Words: ['combat', 'quest', 'puzzle', 'world', 'bit', 'little', 'village', 'rpg', 'explore', 'pretty']
# Box Cat Bash - Positive Words: ['bough gaming', 'friend', 'experience', 'experience beautiful', 'bough', 'bastard', 'beautiful', 'love bough', 'love', 'beautiful bastard']
# DARK SOULS™ III - Positive Words: ['soul', 'dark', 'dark soul', 'boss', 'hard', 'love', 'ring', 'elden', 'elden ring', 'amazing']
# Resident Evil 4 - Positive Words: ['remake', 'evil', 'resident', 'resident evil', 'original', 'love', 'amazing', 'story', 'masterpiece', 'leon']
# Battlefield™ 2042 - Positive Words: ['battlefield', 'amazing', 'love', 'sale', 'launch', 'bf', 'awesome', 'highly', 'cod', 'worth']
# Age of Empires II: Definitive Edition - Positive Words: ['classic', 'rt', 'love', 'strategy', 'friend', 'aoe', 'awesome', 'old', 'year', 'age']
# Ravenfield - Positive Words: ['mod', 'love', 'amazing', 'cool', 'war', 'super', 'sandbox', 'fps', 'modding', 'base']
# Split Fiction - Positive Words: ['story', 'amazing', 'coop', 'experience', 'friend', 'love', 'level', 'hazelight', 'fiction', 'split']
# MapleStory - Positive Words: ['server', 'old', 'level', 'start', 'friend', 'day', 'anymore', 'easy', 'different', 'old maplestory']
# Far Cry® 4 - Positive Words: ['far', 'story', 'love', 'graphic', 'series', 'amazing', 'character', 'ubisoft', 'farcry', 'beautiful']
# Company of Heroes 3 - Positive Words: ['rt', 'coh', 'love', 'launch', 'graphic', 'multiplayer', 'strategy', 'campaign', 'release', 'year']
# Artifact - Positive Words: ['valve murder', 'valve', 'murder']
# Red Dead Redemption 2 - Positive Words: ['story', 'amazing', 'graphic', 'world', 'character', 'experience', 'online', 'open', 'beautiful', 'open world']
# Space Engineers - Positive Words: ['space', 'build', 'love', 'cool', 'ship', 'engineer', 'physics', 'spend', 'sandbox', 'learn']
# Kingdom Come: Deliverance II - Positive Words: ['story', 'quest', 'combat', 'rpg', 'world', 'amazing', 'year', 'love', 'character', 'experience']
# Sekiro™: Shadows Die Twice - GOTY Edition - Positive Words: ['combat', 'hard', 'die', 'boss', 'soul', 'fight', 'amazing', 'sekiro', 'satisfy', 'twice']
# Warhammer 40,000: Space Marine 2 - Positive Words: ['campaign', 'story', 'space', 'marine', 'combat', 'warhammer', 'emperor', 'graphic', 'space marine', 'mode']
# Assassin's Creed® Origins - Positive Words: ['ac', 'love', 'story', 'creed', 'graphic', 'assassin', 'egypt', 'assassin creed', 'ancient', 'amazing']
# NBA 2K25 - Positive Words: ['graphic', 'basketball', 'nba', 'pc', 'mode', 'worth', 'people', 'friend', 'sale', 'love']
# Far Cry® 5 - Positive Words: ['far', 'story', 'farcry', 'love', 'ubisoft', 'amazing', 'world', 'friend', 'open', 'sale']
# The Survivalists - Positive Words: ['monkey', 'relax', 'friend', 'gg', 'wow', 'figure', 'overall', 'survival', 'cute', 'love']
# Star Wars Outlaws - Positive Words: ['star', 'war', 'star war', 'story', 'sale', 'world', 'far', 'pretty', 'ubisoft', 'love']
# Tom Clancy's Rainbow Six® Siege - Positive Words: ['friend', 'love', 'people', 'amazing', 'siege', 'rank', 'shooter', 'learn', 'hard', 'pretty']
# Portal 2 - Positive Words: ['story', 'puzzle', 'portal', 'coop', 'love', 'amazing', 'level', 'valve', 'friend', 'hard']
# Unknown Game - Positive Words: ['soul', 'anime', 'story', 'code', 'dark', 'vein', 'code vein', 'expect', 'io', 'dark soul']
# Europa Universalis IV - Positive Words: ['strategy', 'hate', 'tutorial', 'love', 'harasho', 'gud', 'dd', 'alright', 'cinema', 'learn']
# Stardew Valley - Positive Words: ['love', 'farming', 'relax', 'amazing', 'stardew', 'cozy', 'farm', 'mod', 'friend', 'chill']
# Thief - Positive Words: ['thief', 'cool', 'story', 'thieving', 'wadscfsgbnhb', 'jumpscare', 'favorate', 'steamhappy', 'love', 'old']
# FINAL FANTASY X/X-2 HD Remaster - Positive Words: ['fantasy', 'final', 'love', 'final fantasy', 'story', 'franchise', 'classic', 'character', 'belove', 'year']
# The Sims™ 4 - Positive Words: ['love', 'sim', 'life', 'mod', 'love sim', 'pack', 'sims', 'awsome', 'addict', 'spend']
# ELDEN RING - Positive Words: ['boss', 'hard', 'soul', 'world', 'elden', 'ring', 'elden ring', 'amazing', 'beat', 'story']
# PAYDAY 2 - Positive Words: ['payday', 'love', 'bag', 'friend', 'medic', 'heist', 'amazing', 'medic bag', 'cool', 'bank']
# Elementary Anatomy: With Story Mode - Positive Words: ['mode', 'layer', 'tool', 'learn', 'ant', 'ant mode', 'anatomy', 'female', 'improve', 'cut']
# Mafia: Definitive Edition - Positive Words: ['story', 'mafia', 'amazing', 'love', 'remake', 'graphic', 'masterpiece', 'definitive', 'experience', 'car']
# No Man's Sky - Positive Words: ['space', 'love', 'exploration', 'year', 'explore', 'amazing', 'planet', 'content', 'launch', 'free']
# Dead Cells - Positive Words: ['love', 'cell', 'dead', 'roguelike', 'hard', 'die', 'amazing', 'dead cell', 'rogue', 'combat']
# Elite Dangerous - Positive Words: ['space', 'sim', 'space sim', 'love', 'elite', 'ship', 'vr', 'star', 'year', 'galaxy']
# Deep Rock Galactic - Positive Words: ['rock', 'stone', 'rock stone', 'friend', 'bug', 'coop', 'dwarf', 'amazing', 'beer', 'community']
# Planet Coaster - Positive Words: ['coaster', 'park', 'love', 'amazing', 'awesome', 'planet', 'planet coaster', 'money', 'ye', 'build']
# X-Morph: Defense - Positive Words: ['tower', 'defense', 'tower defense', 'strategy', 'pretty', 'lie', 'hella', 'hella lie', 'genre', 'enemy']
# Shadowrun Returns - Positive Words: ['shadowrun', 'story', 'worth', 'pretty', 'look', 'rpg', 'job', 'basic', 'turn', 'surprisingly look']
# Atomic Heart - Positive Words: ['story', 'love', 'interesting', 'bioshock', 'robot', 'cool', 'look', 'world', 'combat', 'amazing']

# %%
for index, row in df_top_words.iterrows():
    print(f"{row['Game']} - Negative Words: {row['Top_Negative_Words']}")
# Out:
# Fallout 4 - Negative Words: ['mod', 'crash', 'fallout', 'load', 'bethesda', 'bug', 'patch', 'know', 'break', 'gen']
# Phasmophobia - Negative Words: ['ghost', 'lobby', 'map', 'rework', 'community', 'release', 'year', 'scary', 'slow', 'properly']
# Battlefield 4™ - Negative Words: ['punkbuster', 'server', 'kick', 'bug', 'multiplayer', 'ea', 'kick punkbuster', 'minute', 'campaign', 'run']
# Terraria - Negative Words: ['que', 'crringe', 'boss', 'leave', 'leave crringe', 'crringe jk', 'jk salty', 'ranaway', 'ranaway becasue', 'salty']
# Cursed to Golf - Negative Words: ['stroke', 'card', 'weird', 'tutorial', 'golf', 'use', 'suffer', 'kind', 'half', 'design']
# Satisfactory - Negative Words: ['barely', 'bug', 'crash', 'build', 'grind', 'item', 'blueprint', 'laggy', 'make', 'bug laggy']
# DARK SOULS™ II - Negative Words: ['scholar', 'pointless', 'bpre', 'garbage', 'shit', 'version', 'scholar version', 'ass', 'enemy', 'shit ass']
# Counter-Strike 2 - Negative Words: ['cheater', 'valve', 'cheat', 'hacker', 'anticheat', 'vac', 'ban', 'unplayable', 'team', 'anti']
# Monster Hunter: World - Negative Words: ['monster', 'combat', 'hunter', 'monster hunter', 'look', 'fight', 'hate', 'ip', 'attack', 'mechanic']
# Windblown - Negative Words: ['dead cell', 'cell', 'dead', 'op', 'crash', 'level', 'melee', 'deck', 'steam deck', 'steam']
# Dota 2 - Negative Words: ['shit', 'stupid', 'hear nerd', 'ew', 'nerd ew', 'hear', 'nerd', 'toxic', 'auto', 'toxic auto']
# My Time at Sandrock - Negative Words: ['multiplayer', 'controller unplayable', 'axis', 'unplayable', 'invert axis', 'controller', 'axis controller', 'invert', 'story', 'sandrock']
# Titanfall® 2 - Negative Words: ['ea', 'campaign', 'fuck', 'run', 'launcher', 'start', 'pc', 'join', 'ea launcher', 'past']
# 100% Orange Juice - Negative Words: ['shorter annoying', 'ladder', 'annoying luck', 'base', 'chute', 'chute ladder', 'shorter', 'instead', 'instead shorter', 'annoying']
# Pathfinder: Kingmaker — Enhanced Plus Edition - Negative Words: ['combat', 'nah', 'pathfinder', 'encounter', 'terrible', 'bs', 'balancing', 'terrible balancing', 'story', 'experience']
# Keep Driving - Negative Words: ['run', 'people', 'cash', 'place', 'combat', 'drive', 'event', 'buck', 'hitchhiker', 'pretty']
# Valheim - Negative Words: ['biome', 'boss', 'world', 'save', 'year', 'grind', 'ashland', 'mechanic', 'enemy', 'developer']
# PUBG: BATTLEGROUNDS - Negative Words: ['cheater', 'shit', 'hacker', 'lag', 'dog', 'suck', 'china', 'meh', 'ban', 'cheat']
# ARK: Survival Ascended - Negative Words: ['ark', 'crash', 'server', 'run', 'money', 'bug', 'mod', 'graphic', 'evolve', 'survival']
# Sid Meier’s Civilization® VI - Negative Words: ['civ', 'crash', 'ai', 'year', 'turn', 'strategy', 'shit', 'change', 'single', 'look']
# DiRT Rally - Negative Words: []
# Crusader Kings III - Negative Words: ['doo', 'lose', 'paradox', 'love', 'shit', 'start', 'end', 'dlcs', 'doo incest', 'doo doo']
# MONSTER HUNTER RISE - Negative Words: ['monster', 'world', 'remove', 'clunky', 'joke', 'mid', 'drm', 'monster hunter', 'hunter', 'suck']
# Baldur's Gate 3 - Negative Words: ['level', 'character', 'gear', 'look', 'pick', 'class', 'caster', 'cap', 'useful', 'change']
# Yakuza 0 - Negative Words: ['bore', 'overrate', 'kiryu', 'sex', 'majima', 'majima sex', 'freeze', 'damn', 'damn kiryu', 'freeze damn']
# CODE VEIN - Negative Words: ['clunky', 'enemy', 'design', 'soul', 'dark', 'map', 'crap', 'complet', 'complet crap', 'dark soul']
# Dead by Daylight - Negative Words: ['killer', 'survivor', 'perk', 'community', 'money', 'toxic', 'match', 'hook', 'win', 'devs']
# The Witcher 3: Wild Hunt - Negative Words: ['combat', 'control', 'npc', 'annoying', 'witcher', 'movement', 'experience', 'kill', 'world', 'super']
# Exanima - Negative Words: ['year', 'devs', 'early access', 'early', 'access', 'ea', 'year ea', 'tech', 'stuff', 'demo']
# Brawlhalla - Negative Words: ['thumb', 'kind', 'battlepass bs', 'brawler', 'brawler offering', 'bs', 'bs thumb', 'debut', 'debut kind', 'ea']
# Destiny 2 - Negative Words: ['content', 'destiny', 'bungie', 'money', 'hate', 'story', 'life', 'love', 'worth', 'year']
# Beast Saga - Negative Words: []
# Rust - Negative Words: ['ban', 'server', 'load', 'people', 'rust', 'run', 'kill', 'reason', 'minute', 'cheater']
# FragPunk - Negative Words: ['beta', 'currency', 'movement', 'different', 'change', 'monetization', 'character', 'review', 'slow', 'gacha']
# Team Fortress 2 - Negative Words: ['valve', 'suck', 'sex', 'year', 'server', 'community', 'experience', 'bot', 'community server', 'butt']
# Black Squad - Negative Words: ['money', 'gun', 'ban', 'shit', 'ban pro', 'toomany cheater', 'toomany', 'developer ban', 'pro', 'cheater developer']
# ARK: Survival Evolved - Negative Words: ['server', 'crash', 'shit', 'buggy', 'mod', 'waste', 'anymore', 'friend', 'ass', 'ark']
# Euro Truck Simulator 2 - Negative Words: ['truck', 'problem', 'unplayable problem', 'change', 'worth', 'unplayable', 'lizzard', 'add lizzard', 'old', 'add']
# Grand Theft Auto V Legacy - Negative Words: ['rockstar', 'online', 'bug', 'gta', 'shit', 'account', 'company', 'garbage', 'support', 'money']
# Age of Empires IV: Anniversary Edition - Negative Words: ['screen', 'aoe', 'build', 'ai', 'issue', 'level', 'pc', 'look', 'age', 'steam']
# Contra Anniversary Collection - Negative Words: ['control', 'keymappe', 'keymappe awful', 'awful', 'awful control', 'feature keyboard', 'keyboard support', 'port miss', 'rom', 'lazy']
# Marvel’s Spider-Man Remastered - Negative Words: ['waste', 'boring', 'story', 'spiderman', 'money', 'boss', 'sound', 'pretty', 'enemy', 'repetitive']
# BONEWORKS - Negative Words: ['run', 'son', 'waayy laggy', 'waayy', 'laggy', 'puzzle', 'mfucke', 'hat', 'hat let', 'let']
# The Binding of Isaac: Rebirth - Negative Words: ['item', 'shit', 'run', 'trash', 'isaac', 'issue', 'rng', 'know', 'launch', 'extremely']
# Barotrauma - Negative Words: ['husk', 'kys', 'capital', 'social', 'social capital', 'qwop social', 'qwop', 'friend', 'barely', 'away']
# Cyberpunk 2077 - Negative Words: []
# Dying Light - Negative Words: ['crash', 'run', 'story', 'die', 'trash', 'stupid', 'light', 'die light', 'fps', 'zombie']
# Darkest Dungeon® II - Negative Words: ['run', 'boss', 'character', 'dungeon', 'kingdom', 'simply', 'hero', 'end', 'mechanic', 'original']
# Mass Effect™ Legendary Edition - Negative Words: ['ea', 'hate', 'app', 'launcher', 'ea app', 'ea launcher', 'require', 'steam', 'force', 'bug']
# 0 Day - Negative Words: []
# Golf With Your Friends - Negative Words: ['friend', 'ts', 'garbage', 'golf', 'map', 'shit', 'suck', 'achievement', 'golf ts', 'suck donkeyballz']
# Cookie Clicker - Negative Words: ['cookie', 'life', 'addict', 'progress', 'corrupt', 'accidentally corrupt', 'accidentally', 'clicker', 'slog', 'achievement']
# Beat Saber - Negative Words: ['mod', 'song', 'actually', 'music', 'money', 'devs', 'fuck mod', 'mod song', 'fuck', 'music pack']
# Tower Unite - Negative Words: ['report', 'devs', 'spend crash', 'actually', 'crash report', 'crash', 'spend', 'report actually', 'road', 'server']
# Lossless Scaling - Negative Words: ['frame', 'fps', 'use', 'minecraft', 'lossless', 'scale', 'app', 'software', 'slow', 'monitor']
# Robin Hood - Sherwood Builders - Negative Words: ['involve point', 'craft involve', 'simply craft', 'point', 'point chore', 'involve', 'simply', 'chore', 'craft', 'ai']
# Box Cat Bash - Negative Words: []
# DARK SOULS™ III - Negative Words: ['soul', 'dark', 'dark soul', 'boss', 'ring', 'elden', 'elden ring', 'problem', 'dollar', 'insane dollar']
# Resident Evil 4 - Negative Words: ['constant', 'story', 'evil', 'resident', 'resident evil', 'minute', 'setting', 'medium setting', 'medium', 'constant crash']
# Battlefield™ 2042 - Negative Words: ['ea', 'battlefield', 'money', 'crash', 'bf', 'kill', 'waste', 'waste money', 'terrible', 'trash']
# Age of Empires II: Definitive Edition - Negative Words: ['classic', 'unit', 'internet', 'hard', 'bug', 'stop', 'connection', 'developer', 'past', 'nostalgia']
# Ravenfield - Negative Words: ['booooooooooooooooooooooooo', 'mod', 'year', 'dalet', 'mad', 'dalet mad', 'weapon', 'map', 'playwork', 'alive']
# Split Fiction - Negative Words: ['story', 'world', 'character', 'worth', 'help', 'ea', 'user', 'datum', 'issue', 'pass']
# MapleStory - Negative Words: ['server', 'kill', 'animal', 'quest', 'bug', 'level', 'understand', 'lest', 'pretty', 'repetitive']
# Far Cry® 4 - Negative Words: ['ubisoft', 'suck', 'launcher', 'far', 'connect', 'garbage', 'mechanic', 'launch', 'fuck', 'open']
# Company of Heroes 3 - Negative Words: ['win', 'unit', 'relic', 'money', 'coh', 'instead', 'campaign', 'tank', 'balance', 'content']
# Artifact - Negative Words: []
# Red Dead Redemption 2 - Negative Words: []
# Space Engineers - Negative Words: ['design', 'wasd', 'dlcs', 'tutorial', 'build', 'unpolished', 'forget', 'mid forget', 'mid', 'clunky unpolished']
# Kingdom Come: Deliverance II - Negative Words: ['quest', 'kcd', 'medieval', 'run', 'guard', 'literally', 'choice', 'combat', 'town', 'year']
# Sekiro™: Shadows Die Twice - GOTY Edition - Negative Words: ['controller', 'boss', 'pc', 'block', 'camera', 'combat', 'support', 'enemy', 'input', 'fight']
# Warhammer 40,000: Space Marine 2 - Negative Words: ['crash', 'issue', 'campaign', 'run', 'mission', 'saber', 'problem', 'pvp', 'enemy', 'marine']
# Assassin's Creed® Origins - Negative Words: ['ubisoft', 'connect', 'ubisoft connect', 'ac', 'account', 'mediocre', 'open', 'require', 'story', 'force']
# NBA 2K25 - Negative Words: ['crash', 'pc', 'money', 'year', 'run', 'trash', 'basketball', 'shit', 'online', 'mode']
# Far Cry® 5 - Negative Words: ['ubisoft', 'story', 'connect', 'bug', 'ubisoft connect', 'spend', 'far', 'boring', 'save', 'know']
# The Survivalists - Negative Words: ['craft', 'monkey', 'tell', 'save', 'look', 'monekys', 'leik', 'leik monekys', 'movement odd', 'odd tell']
# Star Wars Outlaws - Negative Words: ['crash', 'ubisoft', 'load', 'war', 'star', 'star war', 'story', 'screen', 'connect', 'look']
# Tom Clancy's Rainbow Six® Siege - Negative Words: ['ubisoft', 'crash', 'ban', 'fuck', 'cheater', 'shit', 'server', 'make', 'year', 'suck']
# Portal 2 - Negative Words: ['wall', 'boring probably', 'retarded', 'boring', 'probably', 'probably retarded', 'support', 'support local', 'run fps', 'run']
# Unknown Game - Negative Words: ['clunky', 'enemy', 'design', 'soul', 'dark', 'map', 'crap', 'complet', 'complet crap', 'dark soul']
# Europa Universalis IV - Negative Words: ['money migraine', 'migraine', 'money', 'card', 'dlcs', 'strategy', 'spend', 'scumbag', 'pound', 'spend pound']
# Stardew Valley - Negative Words: ['bug', 'steamdeck incubator', 'incubator', 'patch', 'steamdeck', 'incubator bug', 'bug patch', 'buggy steamdeck', 'buggy', 'button task']
# Thief - Negative Words: ['bore', 'type boring', 'clunky', 'boring', 'nightmare', 'clunky nightmare', 'type', 'story', 'open', 'pretty']
# FINAL FANTASY X/X-2 HD Remaster - Negative Words: ['crash', 'english', 'cutscene crash', 'cutscene', 'quit', 'blitzball quit', 'refund', 'blitzball', 'scene', 'green']
# The Sims™ 4 - Negative Words: ['sim', 'ea', 'pack', 'mod', 'content', 'break', 'sims', 'boring', 'free', 'suck']
# ELDEN RING - Negative Words: []
# PAYDAY 2 - Negative Words: ['fuck', 'start', 'violence', 'break', 'dislike', 'suck', 'dlcs', 'cash', 'buggy', 'people']
# Elementary Anatomy: With Story Mode - Negative Words: ['unpolished', 'interface extremely', 'interface', 'extremely clumsy', 'extremely', 'controller interface', 'controller', 'clumsy unpolished', 'clumsy']
# Mafia: Definitive Edition - Negative Words: ['fullscreen', 'screen', 'launch', 'crash', 'race', 'mafia', 'run', 'drive', 'issue', 'worth']
# No Man's Sky - Negative Words: ['bug', 'base', 'planet', 'progress', 'launch', 'build', 'space', 'world', 'fps', 'setting']
# Dead Cells - Negative Words: ['control responsive', 'responsive', 'control', 'bore', 'hard', 'hogass', 'roguelike', 'rouge', 'dead', 'dead cell']
# Elite Dangerous - Negative Words: ['ship', 'grind', 'mission', 'space', 'tutorial', 'server', 'vr', 'year', 'planet', 'refund']
# Deep Rock Galactic - Negative Words: ['mod', 'friend', 'focus', 'upgrade', 'experience', 'stuck', 'mission', 'shit', 'make', 'repetitive']
# Planet Coaster - Negative Words: ['buit', 'worth', 'cool', 'cool ride', 'ride', 'coaster', 'build', 'hard', 'building', 'park']
# X-Morph: Defense - Negative Words: ['screen', 'look', 'look boring', 'boring', 'boring quickly', 'quickly', 'set', 'default', 'default screen', 'launch']
# Shadowrun Returns - Negative Words: ['sequel', 'miss', 'okay', 'forgettable ending', 'trilogy definitely', 'trilogy', 'shadowrun', 'shadowrun trilogy', 'definitely', 'ending okay']
# Atomic Heart - Negative Words: ['weird', 'difficult', 'robot', 'story', 'bug', 'character', 'main', 'combat', 'dialogue', 'fight']

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Select a game for visualization
selected_game = "The Witcher 3: Wild Hunt"  # Change this to any game you want

# Extract positive and negative words for the selected game
game_data = df_top_words[df_top_words["Game"] == selected_game]

if not game_data.empty:
    pos_words = game_data["Top_Positive_Words"].values[0]
    neg_words = game_data["Top_Negative_Words"].values[0]

    # Convert lists to space-separated strings
    pos_text = " ".join(pos_words)
    neg_text = " ".join(neg_words)

    # Create figure for side-by-side word clouds
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))

    # Generate Positive Word Cloud
    wordcloud_pos = WordCloud(width=500, height=500, background_color="white").generate(pos_text)
    axes[0].imshow(wordcloud_pos, interpolation="bilinear")
    axes[0].axis("off")
    axes[0].set_title(f"Positive Reviews - {selected_game}", fontsize=14)

    # Generate Negative Word Cloud
    wordcloud_neg = WordCloud(width=500, height=500, background_color="black", colormap="Reds").generate(neg_text)
    axes[1].imshow(wordcloud_neg, interpolation="bilinear")
    axes[1].axis("off")
    axes[1].set_title(f"Negative Reviews - {selected_game}", fontsize=14)

    # Show the word clouds
    plt.show()
else:
    print(f"No data found for {selected_game}")

# %%
# Creating a DataFrame with extended user reviews
user_reviews = pd.DataFrame({
    "Game": [
        "The Witcher 3: Wild Hunt", 
        "Dark Souls 3", 
        "X-Morph: Defense", 
        "Cyberpunk 2077", 
        "Horizon Zero Dawn",
        "Assassin’s Creed Valhalla"
    ],
    "review": [
        "I really enjoyed The Witcher 3 because of its vast open world, deep story, and breathtaking graphics. The game offers an immersive experience with well-developed characters and rich lore. The combat mechanics feel smooth, and there are countless side quests that add depth to the world. However, it required a very strong PC, and I experienced frequent crashes, which sometimes ruined the immersion.",
        
        "Dark Souls 3 was an amazing experience. The quest design is intricate, and the story, though subtle, is deeply engaging for those who invest time in understanding the lore. The combat is extremely challenging but rewarding, requiring precision and strategy. The boss fights are intense and satisfying, though some of them felt repetitive. Additionally, certain difficulty spikes felt unbalanced, making progression frustrating at times.",
        
        "I did not like X-Morph: Defense because it's a tower defense game, and I’m not into that genre. The game lacks a compelling story, and the graphics felt outdated compared to modern strategy games. The gameplay quickly became repetitive, and there wasn't much variety in the mechanics. It didn’t hold my interest for long, and I found myself getting bored after a few levels.",
        
        "Cyberpunk 2077 had a lot of potential with its futuristic open world and deep RPG mechanics. The city felt alive with plenty of characters and side quests. However, the game was plagued with technical issues, including game-breaking bugs, crashes, and unoptimized performance. While the main story was engaging, the overall experience was disappointing due to the lack of polish at launch.",
        
        "Horizon Zero Dawn was an incredible game with a unique blend of open-world exploration, a strong protagonist, and a compelling sci-fi story. The combat felt dynamic, and the world was beautifully crafted with breathtaking landscapes. The enemy AI was intelligent, and each fight required strategy. The only downside was that some side missions felt repetitive after a while, but overall, it was an amazing experience.",
        
        "Assassin’s Creed Valhalla was an enjoyable game for the most part. The Viking setting was immersive, and the world was rich with details. The combat felt weighty, and there were plenty of things to do. However, I found the progression system to be too grindy, and the game felt repetitive after some time. The story, while engaging at first, started to lose its impact halfway through. The overall experience was decent but not exceptional."
    ],
    "recommended": [
        "True", 
        "True", 
        "False", 
        "False", 
        "True", 
        "False"
    ]
})
game_metadata = pd.DataFrame({
    "Game": ["The Witcher 3: Wild Hunt", "Dark Souls 3", "X-Morph: Defense", "Cyberpunk 2077", "Horizon Zero Dawn", "Assassin’s Creed Valhalla"],
    "genre": ["RPG, Open World", "Action, RPG", "Strategy, Tower Defense", "Action, RPG, Open World", "Action, Adventure", "Action, RPG"],
    "action": [False, True, False, True, True, True],
    "strategy": [False, False, True, False, False, False],
    "free_to_play": [False, False, False, False, False, False],
    "adventure": [True, False, False, True, True, True],
    "massively_multiplayer": [False, False, False, False, False, False],
    "indie": [False, False, False, False, False, False],
    "rpg": [True, True, False, True, True, True],
    "casual": [False, False, False, False, False, False],
    "racing": [False, False, False, False, False, False],
    "early_access": [False, False, False, False, False, False],
    "simulation": [False, False, False, False, False, False],
    "unknown_genre": [False, False, False, False, False, False],
    "sports": [False, False, False, False, False, False],
    "violent": [True, True, False, True, False, True],
    "education": [False, False, False, False, False, False],
    "utilities": [False, False, False, False, False, False]
})
user_reviews = user_reviews.merge(game_metadata, on="Game", how="left")

# Display the DataFrame
print(user_reviews)
# Out:
#                         Game  \
# 0   The Witcher 3: Wild Hunt
# 1               Dark Souls 3
# 2           X-Morph: Defense
# 3             Cyberpunk 2077
# 4          Horizon Zero Dawn
# 5  Assassin’s Creed Valhalla
#
#                                               review recommended  \
# 0  I really enjoyed The Witcher 3 because of its ...        True
# 1  Dark Souls 3 was an amazing experience. The qu...        True
# 2  I did not like X-Morph: Defense because it's a...       False
# 3  Cyberpunk 2077 had a lot of potential with its...       False
# 4  Horizon Zero Dawn was an incredible game with ...        True
# 5  Assassin’s Creed Valhalla was an enjoyable gam...       False
#
#                      genre  action  strategy  free_to_play  adventure  \
# 0          RPG, Open World   False     False         False       True
# 1              Action, RPG    True     False         False      False
# 2  Strategy, Tower Defense   False      True         False      False
# 3  Action, RPG, Open World    True     False         False       True
# 4        Action, Adventure    True     False         False       True
# 5              Action, RPG    True     False         False       True
#
#    massively_multiplayer  indie    rpg  casual  racing  early_access  \
# 0                  False  False   True   False   False         False
# 1                  False  False   True   False   False         False
# 2                  False  False  False   False   False         False
# 3                  False  False   True   False   False         False
# 4                  False  False   True   False   False         False
# 5                  False  False   True   False   False         False
#
#    simulation  unknown_genre  sports  violent  education  utilities
# 0       False          False   False     True      False      False
# 1       False          False   False     True      False      False
# 2       False          False   False    False      False      False
# 3       False          False   False     True      False      False
# 4       False          False   False    False      False      False
# 5       False          False   False     True      False      False

# %%
import os
import re
import csv
import sys
import subprocess
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, SnowballStemmer, PorterStemmer
from nltk.corpus import stopwords
import spacy
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer, TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from tqdm import tqdm

from scipy.stats import pearsonr

# Function to download NLTK resources
def download_nltk_resources():
    required_resources = ['wordnet', 'stopwords', 'punkt']
    for resource in required_resources:
        try:
            nltk.data.find(f'tokenizers/{resource}' if resource == 'punkt' else f'corpora/{resource}')
        except LookupError:
            nltk.download(resource)

download_nltk_resources()

# Function to install and load spaCy model
def install_spacy_model(model_name):
    try:
        return spacy.load(model_name)
    except OSError:
        print(f"Downloading spaCy model: {model_name}")
        subprocess.check_call([sys.executable, "-m", "spacy", "download", model_name])
        return spacy.load(model_name)

sp = install_spacy_model('en_core_web_sm')

# Enable tqdm for pandas
tqdm.pandas()

# Initialize stemmers and lemmatizer
porter = SnowballStemmer("english")
lmtzr = WordNetLemmatizer()
STOP_WORDS = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package wordnet to /home/oliver/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /home/oliver/miniconda3/envs/Textmining_2/lib/python3.12/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_web_sm' (3.8.0) was trained with spaCy v3.8.0 and may not be 100% compatible with the current version (3.7.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
"""
This module provides helper functions for text preprocessing. 
Each function applies punctuation removal and stopword removal, and then one of three options:
    0: Lowercasing only.
    1: Lowercasing plus stemming.
    2: Lemmatizing (using spaCy; original casing is preserved).

The functions return a string of tokens separated by spaces.
"""


def preprocess_lower(text):
    """
    Preprocess text by:
       - Converting to lowercase.
       - Removing punctuation.
       - Tokenizing.
       - Removing stopwords.
    
    Returns:
        str: A string of filtered tokens separated by spaces.
    """
    text_lower = text.lower()
    text_no_punct = re.sub(r'[^\w\s]', '', text_lower)
    tokens = word_tokenize(text_no_punct)
    filtered_tokens = [token for token in tokens if token not in STOP_WORDS]
    return " ".join(filtered_tokens)

def preprocess_stem(text):
    """
    Preprocess text by performing all steps in preprocess_lower() and then applying stemming.
    
    Returns:
        str: A string of stemmed tokens separated by spaces.
    """
    tokens = preprocess_lower(text).split()
    ps = PorterStemmer()
    stemmed_tokens = [ps.stem(token) for token in tokens]
    return " ".join(stemmed_tokens)


# Function to remove emojis and special characters
def clean_text(text):
    text = re.sub(r'\[.*?\]', '', text)  # Remove HTML-like tags [b], [i], etc.
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)  # Keeps letters, numbers, and spaces
    return text

# Updated preprocess_lemma function
def preprocess_lemma(text):
    """
    Preprocess text by:
       - Removing special characters, emojis, and HTML tags.
       - Lemmatizing the text using spaCy.
       - Keeping only alphabetic words (removes numbers & symbols).
    
    Returns:
        str: A string of lemmatized words separated by spaces.
    """
    # Load spaCy model
    nlp = spacy.load("en_core_web_sm")
    text = clean_text(text)  # Remove special characters
    doc = nlp(text)  # Process text with spaCy
    lemmatized_tokens = [token.lemma_ for token in doc if not token.is_stop and token.is_alpha]  # Keep only words
    return " ".join(lemmatized_tokens)



def tokenize(text, mode=0):
    """
    General tokenize function. Always applies punctuation and stopword removal and then:
    
      mode = 0: Applies lowercasing.
      mode = 1: Applies lowercasing and stemming.
      mode = 2: Applies lemmatization (without lowercasing the original text).
    
    Args:
        text (str): The input text to be processed.
        mode (int): Processing mode (0 for lowercasing; 1 for stemming; 2 for lemmatizing).

    Returns:
        str: A string of processed tokens separated by spaces.

    Raises:
        ValueError: If an invalid mode is provided.
    """
    if mode == 0:
        return preprocess_lower(text)
    elif mode == 1:
        return preprocess_stem(text)
    elif mode == 2:
        return preprocess_lemma(text)
    else:
        raise ValueError("Invalid mode. Please use 0 for lowercasing, 1 for stemming, or 2 for lemmatizing.")

# %%
#Getting the clean text column
mod=2 #Lemmatizing

# Pre-process the text column with progress tracking
try:
    user_reviews["cleaned_review"] = user_reviews["review"].progress_apply(lambda x: tokenize(str(x), mod))
    print("Done processing text.")
except Exception as e:
    print(f"Error processing text column: {e}")
    sys.exit(1)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]/home/oliver/miniconda3/envs/Textmining_2/lib/python3.12/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_web_sm' (3.8.0) was trained with spaCy v3.8.0 and may not be 100% compatible with the current version (3.7.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# 100%|██████████| 6/6 [00:02<00:00,  2.11it/s]
# Done processing text.

# %%
pos_reviews_cleaned = user_reviews[user_reviews["recommended"] == "True"].copy()
neg_reviews_cleaned = user_reviews[user_reviews["recommended"] == "False"].copy()
pos_reviews_cleaned = pos_reviews_cleaned.dropna(subset=['cleaned_review'])
pos_reviews_cleaned["cleaned_review"] = pos_reviews_cleaned["cleaned_review"].apply(remove_custom_stopwords)

# Remove NaN values and apply custom stopwords removal for negative reviews
neg_reviews_cleaned = neg_reviews_cleaned.dropna(subset=['cleaned_review'])
neg_reviews_cleaned["cleaned_review"] = neg_reviews_cleaned["cleaned_review"].apply(remove_custom_stopwords)

vectorizer_pos = TfidfVectorizer(stop_words="english", ngram_range=(1,2), max_features=5000)
vectorizer_neg = TfidfVectorizer(stop_words="english", ngram_range=(1,2), max_features=5000)

# Step 3: Apply TF-IDF on positive reviews
tfidf_matrix_pos = vectorizer_pos.fit_transform(pos_reviews_cleaned["cleaned_review"])
terms_pos = vectorizer_pos.get_feature_names_out()

# Step 4: Apply TF-IDF on negative reviews
tfidf_matrix_neg = vectorizer_neg.fit_transform(neg_reviews_cleaned["cleaned_review"])
terms_neg = vectorizer_neg.get_feature_names_out()

# Step 5: Compute Mean TF-IDF Scores
tfidf_sum_pos = tfidf_matrix_pos.mean(axis=0).A1
tfidf_sum_neg = tfidf_matrix_neg.mean(axis=0).A1

# Step 6: Create DataFrames with TF-IDF scores
tfidf_df_pos = pd.DataFrame({'term': terms_pos, 'tfidf_score': tfidf_sum_pos}).sort_values(by="tfidf_score", ascending=False)
tfidf_df_neg = pd.DataFrame({'term': terms_neg, 'tfidf_score': tfidf_sum_neg}).sort_values(by="tfidf_score", ascending=False)

# Step 7: Display the TF-IDF DataFrames
print("\nTop Positive User Profile TF-IDF Terms:\n", tfidf_df_pos.head(10))
print("\nTop Negative User Profile TF-IDF Terms:\n", tfidf_df_neg.head(10))
# Out:
# Top Positive User Profile TF-IDF Terms:
#               term  tfidf_score
# 57     experience     0.103588
# 164         world     0.100936
# 120       require     0.077431
# 23         combat     0.077431
# 140         story     0.077431
# 14   breathtaking     0.067254
# 147        strong     0.067254
# 114         quest     0.066135
# 90           lore     0.066135
# 91    lore combat     0.066135
#
# Top Negative User Profile TF-IDF Terms:
#                     term  tfidf_score
# 28              defense     0.106637
# 112               story     0.087025
# 101          repetitive     0.078351
# 64                 lack     0.074260
# 73             mechanic     0.074260
# 82              overall     0.071511
# 39           experience     0.071511
# 88               plenty     0.071511
# 113        story engage     0.071511
# 83   overall experience     0.071511

# %%
pos_reviews_cleaned
# Out:
#                        Game  \
# 0  The Witcher 3: Wild Hunt
# 1              Dark Souls 3
# 4         Horizon Zero Dawn
#
#                                               review recommended  \
# 0  I really enjoyed The Witcher 3 because of its ...        True
# 1  Dark Souls 3 was an amazing experience. The qu...        True
# 4  Horizon Zero Dawn was an incredible game with ...        True
#
#                genre  action  strategy  free_to_play  adventure  \
# 0    RPG, Open World   False     False         False       True
# 1        Action, RPG    True     False         False      False
# 4  Action, Adventure    True     False         False       True
#
#    massively_multiplayer  indie  ...  casual  racing  early_access  \
# 0                  False  False  ...   False   False         False
# 1                  False  False  ...   False   False         False
# 4                  False  False  ...   False   False         False
#
#    simulation  unknown_genre  sports  violent  education  utilities  \
# 0       False          False   False     True      False      False
# 1       False          False   False     True      False      False
# 4       False          False   False    False      False      False
#
#                                       cleaned_review
# 0  Witcher vast open world deep story breathtakin...
# 1  Dark Souls amazing experience quest design int...
# 4  Horizon Zero Dawn incredible unique blend open...
#
# [3 rows x 21 columns]

# %% [markdown]
# tfidf_df_pos = positive terms from the User
#
# tfidf_df_neg = negative terms from the User
#
# df_top_words = terms for all games, pos and negative.

# %%
# Convert TF-IDF dataframes into dictionaries for fast lookup
user_pos_profile = dict(zip(tfidf_df_pos["term"], tfidf_df_pos["tfidf_score"]))
user_neg_profile = dict(zip(tfidf_df_neg["term"], tfidf_df_neg["tfidf_score"]))

from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Function to compute cosine similarity between two TF-IDF vectors
def compute_cosine_similarity(user_profile, game_profile):
    # Create aligned vectors (matching words in both profiles)
    all_terms = set(user_profile.keys()).union(set(game_profile.keys()))

    # Convert profiles into numerical vectors
    user_vector = np.array([user_profile.get(term, 0) for term in all_terms])
    game_vector = np.array([game_profile.get(term, 0) for term in all_terms])

    # Compute cosine similarity
    similarity = cosine_similarity([user_vector], [game_vector])[0][0]
    return similarity

# %%
game_similarity_scores = []
# Iterate through each game and compute similarity
for index, row in df_top_words.iterrows():
    game_name = row["Game"]

    # Convert game terms into dictionaries
    game_pos_profile = dict(zip(row["Top_Positive_Words"], [1]*len(row["Top_Positive_Words"])))
    game_neg_profile = dict(zip(row["Top_Negative_Words"], [1]*len(row["Top_Negative_Words"])))

    # Compute cosine similarity with user profile
    pos_sim = compute_cosine_similarity(user_pos_profile, game_pos_profile)
    neg_sim = compute_cosine_similarity(user_neg_profile, game_neg_profile)

    # Calculate final score (favor positive similarity, penalize negative similarity)
    final_score = pos_sim - neg_sim

    # Store results
    game_similarity_scores.append((game_name, pos_sim, neg_sim, final_score))

# Convert to DataFrame
df_game_recommendations = pd.DataFrame(game_similarity_scores, columns=["Game", "Positive_Similarity", "Negative_Similarity", "Final_Score"])

# Sort by final score
df_game_recommendations = df_game_recommendations.sort_values(by="Final_Score", ascending=False)

# Display recommendations
print(df_game_recommendations.head(10))
# Out:
#                                          Game  Positive_Similarity  \
# 67                      Red Dead Redemption 2             0.269920
# 69               Kingdom Come: Deliverance II             0.275420
# 45                             Cyberpunk 2077             0.224391
# 27                   The Witcher 3: Wild Hunt             0.267704
# 85                                 ELDEN RING             0.147551
# 55             Robin Hood - Sherwood Builders             0.125675
# 70  Sekiro™: Shadows Die Twice - GOTY Edition             0.129606
# 0                                   Fallout 4             0.148382
# 23                            Baldur's Gate 3             0.136300
# 88                  Mafia: Definitive Edition             0.149745
#
#     Negative_Similarity  Final_Score
# 67             0.000000     0.269920
# 69             0.049234     0.226186
# 45             0.000000     0.224391
# 27             0.100913     0.166791
# 85             0.000000     0.147551
# 55             0.000000     0.125675
# 70             0.026025     0.103581
# 0              0.046418     0.101965
# 23             0.051127     0.085173
# 88             0.069626     0.080119

# %% [markdown]
# We can see how most of the recommended games make sense, but not all of them.
# What is very interesting is that we actually recommend The Witcher 3: Wild Hunt, which is a game that we reviewed as positively recommended.
# This makes sense but it should nevertheless not happen so we take it out of range of predictions:

# %%
# Remove games that the user has already reviewed from recommendations
df_filtered_recommendations = df_game_recommendations[~df_game_recommendations["Game"].isin(user_reviews["Game"])]

# Display the updated recommendations without already-reviewed games
print(df_filtered_recommendations)
# Out:
#                                          Game  Positive_Similarity  \
# 67                      Red Dead Redemption 2             0.269920
# 69               Kingdom Come: Deliverance II             0.275420
# 85                                 ELDEN RING             0.147551
# 55             Robin Hood - Sherwood Builders             0.125675
# 70  Sekiro™: Shadows Die Twice - GOTY Edition             0.129606
# ..                                        ...                  ...
# 43              The Binding of Isaac: Rebirth             0.000000
# 9                                   Windblown             0.000000
# 89                               No Man's Sky             0.056626
# 82                                      Thief             0.039800
# 63                                 MapleStory             0.000000
#
#     Negative_Similarity  Final_Score
# 67             0.000000     0.269920
# 69             0.049234     0.226186
# 85             0.000000     0.147551
# 55             0.000000     0.125675
# 70             0.026025     0.103581
# ..                  ...          ...
# 43             0.046418    -0.046418
# 9              0.051127    -0.051127
# 89             0.109887    -0.053261
# 82             0.096694    -0.056895
# 63             0.115361    -0.115361
#
# [94 rows x 4 columns]

# %% [markdown]
# ### Improving Predictions

# %% [markdown]
# To improve our predictions furthermore, we will include the strategy boolean. We will try this in the file Game tfidf_2.ipynb

# %%
user_reviews.head() #Remember we still have our dataframe of user reviews, so let's use the extra features!
# Out:
#                        Game  \
# 0  The Witcher 3: Wild Hunt
# 1              Dark Souls 3
# 2          X-Morph: Defense
# 3            Cyberpunk 2077
# 4         Horizon Zero Dawn
#
#                                               review recommended  \
# 0  I really enjoyed The Witcher 3 because of its ...        True
# 1  Dark Souls 3 was an amazing experience. The qu...        True
# 2  I did not like X-Morph: Defense because it's a...       False
# 3  Cyberpunk 2077 had a lot of potential with its...       False
# 4  Horizon Zero Dawn was an incredible game with ...        True
#
#                      genre  action  strategy  free_to_play  adventure  \
# 0          RPG, Open World   False     False         False       True
# 1              Action, RPG    True     False         False      False
# 2  Strategy, Tower Defense   False      True         False      False
# 3  Action, RPG, Open World    True     False         False       True
# 4        Action, Adventure    True     False         False       True
#
#    massively_multiplayer  indie  ...  casual  racing  early_access  \
# 0                  False  False  ...   False   False         False
# 1                  False  False  ...   False   False         False
# 2                  False  False  ...   False   False         False
# 3                  False  False  ...   False   False         False
# 4                  False  False  ...   False   False         False
#
#    simulation  unknown_genre  sports  violent  education  utilities  \
# 0       False          False   False     True      False      False
# 1       False          False   False     True      False      False
# 2       False          False   False    False      False      False
# 3       False          False   False     True      False      False
# 4       False          False   False    False      False      False
#
#                                       cleaned_review
# 0  enjoy Witcher vast open world deep story breat...
# 1  Dark Souls amazing experience quest design int...
# 2  like XMorph Defense tower defense game m genre...
# 3  cyberpunk lot potential futuristic open world ...
# 4  Horizon Zero Dawn incredible game unique blend...
#
# [5 rows x 21 columns]

# %%
# Define lambda (weighting for feature matching)
lambda_weight = 0.5  # Adjust based on preference (higher = genre matters more)
user_reviews["recommended"] = user_reviews["recommended"].astype(bool)
# Compute the user's preferred feature profile
user_feature_profile = user_reviews[user_reviews["recommended"] == True].drop(
    columns=["Game", "review", "recommended", "genre", "cleaned_review"]
).mean()

# %%
user_feature_profile
# Out:
# action                   0.666667
# strategy                 0.166667
# free_to_play             0.000000
# adventure                0.666667
# massively_multiplayer    0.000000
# indie                    0.000000
# rpg                      0.833333
# casual                   0.000000
# racing                   0.000000
# early_access             0.000000
# simulation               0.000000
# unknown_genre            0.000000
# sports                   0.000000
# violent                  0.666667
# education                0.000000
# utilities                0.000000
# dtype: float64

# %%
df_filtered_recommendations
# Out:
#                                          Game  Positive_Similarity  \
# 67                      Red Dead Redemption 2             0.269920
# 69               Kingdom Come: Deliverance II             0.275420
# 85                                 ELDEN RING             0.147551
# 55             Robin Hood - Sherwood Builders             0.125675
# 70  Sekiro™: Shadows Die Twice - GOTY Edition             0.129606
# ..                                        ...                  ...
# 43              The Binding of Isaac: Rebirth             0.000000
# 9                                   Windblown             0.000000
# 89                               No Man's Sky             0.056626
# 82                                      Thief             0.039800
# 63                                 MapleStory             0.000000
#
#     Negative_Similarity  Final_Score
# 67             0.000000     0.269920
# 69             0.049234     0.226186
# 85             0.000000     0.147551
# 55             0.000000     0.125675
# 70             0.026025     0.103581
# ..                  ...          ...
# 43             0.046418    -0.046418
# 9              0.051127    -0.051127
# 89             0.109887    -0.053261
# 82             0.096694    -0.056895
# 63             0.115361    -0.115361
#
# [94 rows x 4 columns]

# %%
# Display data types of all columns in game_metadata
print(df_filtered_recommendations.dtypes)
# Out:
# Game                    object
# Positive_Similarity    float64
# Negative_Similarity    float64
# Final_Score            float64
# dtype: object

# %%
# Select relevant columns from game_reviews (only genre booleans)
genre_columns = ["Game", "action", "strategy", "free_to_play", "adventure", 
                 "massively_multiplayer", "indie", "rpg", "casual", "racing", 
                 "early_access", "simulation", "unknown_genre", "sports", 
                 "violent", "education", "utilities"]

# Merge df_top_words with game_reviews to add genre booleans
df_top_words = df_top_words.merge(game_reviews[genre_columns], on="Game", how="left")

# Confirm the genres are included
print(df_top_words.head())
# Out:
#         Game                                 Top_Positive_Words  \
# 0  Fallout 4  [fallout, mod, story, love, world, amazing, be...
# 1  Fallout 4  [fallout, mod, story, love, world, amazing, be...
# 2  Fallout 4  [fallout, mod, story, love, world, amazing, be...
# 3  Fallout 4  [fallout, mod, story, love, world, amazing, be...
# 4  Fallout 4  [fallout, mod, story, love, world, amazing, be...
#
#                                   Top_Negative_Words  action  strategy  \
# 0  [mod, crash, fallout, load, bethesda, bug, pat...   False     False
# 1  [mod, crash, fallout, load, bethesda, bug, pat...   False     False
# 2  [mod, crash, fallout, load, bethesda, bug, pat...   False     False
# 3  [mod, crash, fallout, load, bethesda, bug, pat...   False     False
# 4  [mod, crash, fallout, load, bethesda, bug, pat...   False     False
#
#    free_to_play  adventure  massively_multiplayer  indie   rpg  casual  \
# 0         False      False                  False  False  True   False
# 1         False      False                  False  False  True   False
# 2         False      False                  False  False  True   False
# 3         False      False                  False  False  True   False
# 4         False      False                  False  False  True   False
#
#    racing  early_access  simulation  unknown_genre  sports  violent  \
# 0   False         False       False          False   False    False
# 1   False         False       False          False   False    False
# 2   False         False       False          False   False    False
# 3   False         False       False          False   False    False
# 4   False         False       False          False   False    False
#
#    education  utilities
# 0      False      False
# 1      False      False
# 2      False      False
# 3      False      False
# 4      False      False

# %%
genre_columns = ["Game", "action", "strategy", "free_to_play", "adventure", 
                 "massively_multiplayer", "indie", "rpg", "casual", "racing", 
                 "early_access", "simulation", "unknown_genre", "sports", 
                 "violent", "education", "utilities"]

unique_game_features = game_reviews[genre_columns].drop_duplicates(subset=["Game"])

# Merge df_filtered_recommendations with unique game metadata
df_filtered_recommendations = df_filtered_recommendations.merge(
    unique_game_features, on="Game", how="left"
)

# %%
df_filtered_recommendations
# Out:
#                                          Game  Positive_Similarity  \
# 0                       Red Dead Redemption 2             0.269920
# 1                Kingdom Come: Deliverance II             0.275420
# 2                                  ELDEN RING             0.147551
# 3              Robin Hood - Sherwood Builders             0.125675
# 4   Sekiro™: Shadows Die Twice - GOTY Edition             0.129606
# ..                                        ...                  ...
# 89              The Binding of Isaac: Rebirth             0.000000
# 90                                  Windblown             0.000000
# 91                               No Man's Sky             0.056626
# 92                                      Thief             0.039800
# 93                                 MapleStory             0.000000
#
#     Negative_Similarity  Final_Score  action  strategy  free_to_play  \
# 0              0.000000     0.269920    True     False         False
# 1              0.049234     0.226186    True     False         False
# 2              0.000000     0.147551    True     False         False
# 3              0.000000     0.125675   False     False         False
# 4              0.026025     0.103581    True     False         False
# ..                  ...          ...     ...       ...           ...
# 89             0.046418    -0.046418    True     False         False
# 90             0.051127    -0.051127    True     False         False
# 91             0.109887    -0.053261    True     False         False
# 92             0.096694    -0.056895    True     False         False
# 93             0.115361    -0.115361    True     False          True
#
#     adventure  massively_multiplayer  indie    rpg  casual  racing  \
# 0        True                  False  False  False   False   False
# 1        True                  False  False   True   False   False
# 2       False                  False  False   True   False   False
# 3        True                  False   True   True   False   False
# 4        True                  False  False  False   False   False
# ..        ...                    ...    ...    ...     ...     ...
# 89      False                  False  False  False   False   False
# 90      False                  False   True  False   False   False
# 91       True                  False  False  False   False   False
# 92       True                  False  False  False   False   False
# 93       True                   True  False   True    True   False
#
#     early_access  simulation  unknown_genre  sports  violent  education  \
# 0          False       False          False   False    False      False
# 1          False       False          False   False    False      False
# 2          False       False          False   False    False      False
# 3          False       False          False   False    False      False
# 4          False       False          False   False    False      False
# ..           ...         ...            ...     ...      ...        ...
# 89         False       False          False   False    False      False
# 90          True       False          False   False    False      False
# 91         False       False          False   False    False      False
# 92         False       False          False   False    False      False
# 93         False       False          False   False    False      False
#
#     utilities
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ..        ...
# 89      False
# 90      False
# 91      False
# 92      False
# 93      False
#
# [94 rows x 20 columns]

# %%
def compute_feature_match(game_row, user_profile):
    game_features = game_row.drop(labels=["Game", "Positive_Similarity", "Negative_Similarity", "Final_Score"], errors="ignore")
    return np.dot(game_features.values, user_profile.values)

# Apply feature similarity calculation
df_filtered_recommendations["Feature_Match_Score"] = df_filtered_recommendations.apply(
    lambda row: compute_feature_match(row, user_feature_profile), axis=1
)

# %%
df_filtered_recommendations.head()
# Out:
#                                         Game  Positive_Similarity  \
# 0                      Red Dead Redemption 2             0.269920
# 1               Kingdom Come: Deliverance II             0.275420
# 2                                 ELDEN RING             0.147551
# 3             Robin Hood - Sherwood Builders             0.125675
# 4  Sekiro™: Shadows Die Twice - GOTY Edition             0.129606
#
#    Negative_Similarity  Final_Score  action  strategy  free_to_play  \
# 0             0.000000     0.269920    True     False         False
# 1             0.049234     0.226186    True     False         False
# 2             0.000000     0.147551    True     False         False
# 3             0.000000     0.125675   False     False         False
# 4             0.026025     0.103581    True     False         False
#
#    adventure  massively_multiplayer  indie  ...  casual  racing  early_access  \
# 0       True                  False  False  ...   False   False         False
# 1       True                  False  False  ...   False   False         False
# 2      False                  False  False  ...   False   False         False
# 3       True                  False   True  ...   False   False         False
# 4       True                  False  False  ...   False   False         False
#
#    simulation  unknown_genre  sports  violent  education  utilities  \
# 0       False          False   False    False      False      False
# 1       False          False   False    False      False      False
# 2       False          False   False    False      False      False
# 3       False          False   False    False      False      False
# 4       False          False   False    False      False      False
#
#    Feature_Match_Score
# 0             1.333333
# 1             2.166667
# 2             1.500000
# 3             1.500000
# 4             1.333333
#
# [5 rows x 21 columns]

# %%
lambda_weight = 0.5  # Adjust to balance TF-IDF similarity vs. genre similarity
# Step 2: Update the Final Score
df_filtered_recommendations["Final_Score"] = (
    df_filtered_recommendations["Positive_Similarity"] 
    - df_filtered_recommendations["Negative_Similarity"]
    + lambda_weight * df_filtered_recommendations["Feature_Match_Score"]  # Adjust with lambda
)

# Step 3: Sort and display new recommendations
df_filtered_recommendations = df_filtered_recommendations.sort_values(by="Final_Score", ascending=False)

# Display updated recommendations
print(df_filtered_recommendations.head(10))
# Out:
#                                 Game  Positive_Similarity  \
# 1       Kingdom Come: Deliverance II             0.275420
# 67                   Elite Dangerous             0.000000
# 18  Warhammer 40,000: Space Marine 2             0.102364
# 19                          Terraria             0.055870
# 23                          Yakuza 0             0.073736
# 25                           Exanima             0.039800
# 30                              Rust             0.033937
# 36         Assassin's Creed® Origins             0.096501
# 38                      Atomic Heart             0.165418
# 44                           Valheim             0.096504
#
#     Negative_Similarity  Final_Score  action  strategy  free_to_play  \
# 1              0.049234     1.309520    True     False         False
# 67             0.000000     1.166667    True      True         False
# 18             0.046418     1.139280    True     False         False
# 19             0.000000     1.139203    True     False         False
# 23             0.027918     1.129151    True     False         False
# 25             0.000000     1.123133    True     False         False
# 30             0.000000     1.117270    True     False         False
# 36             0.068776     1.111058    True     False         False
# 38             0.141219     1.107532    True     False         False
# 44             0.076327     1.103510    True     False         False
#
#     adventure  massively_multiplayer  indie  ...  casual  racing  \
# 1        True                  False  False  ...   False   False
# 67       True                   True  False  ...   False   False
# 18       True                  False  False  ...   False   False
# 19       True                  False   True  ...   False   False
# 23       True                  False  False  ...   False   False
# 25       True                  False   True  ...   False   False
# 30       True                   True   True  ...   False   False
# 36       True                  False  False  ...   False   False
# 38       True                  False  False  ...   False   False
# 44       True                  False   True  ...   False   False
#
#     early_access  simulation  unknown_genre  sports  violent  education  \
# 1          False       False          False   False    False      False
# 67         False        True          False   False    False      False
# 18         False       False          False   False    False      False
# 19         False       False          False   False    False      False
# 23         False       False          False   False    False      False
# 25          True        True          False   False    False      False
# 30         False       False          False   False    False      False
# 36         False       False          False   False    False      False
# 38         False       False          False   False    False      False
# 44          True       False          False   False    False      False
#
#     utilities  Feature_Match_Score
# 1       False             2.166667
# 67      False             2.333333
# 18      False             2.166667
# 19      False             2.166667
# 23      False             2.166667
# 25      False             2.166667
# 30      False             2.166667
# 36      False             2.166667
# 38      False             2.166667
# 44      False             2.166667
#
# [10 rows x 21 columns]
