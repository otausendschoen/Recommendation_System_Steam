# %% [markdown]
# # Videogame Recommendation System Using Steam Reviews
# Gerardo Gómez Argüelles, Tirdod Behbehani, & Oliver Tausendschön

# %% [markdown]
# ## Feature Extraction (TF-IDF) / Game Characteristics

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import re

# %%
game_reviews = pd.read_csv("all_Steam_Reviews_cleaned_1.csv")
pos_reviews=pd.read_csv("positive_steam_reviews_1.csv")
neg_reviews=pd.read_csv("negative_steam_reviews_1.csv")

# %%
#avoid error later
pos_reviews.rename(columns={'game': 'Game'}, inplace=True)
neg_reviews.rename(columns={'game': 'Game'}, inplace=True)
game_reviews.rename(columns={'game': 'Game'}, inplace=True)

# %% [markdown]
# In our data set we have some NA's so we decided to drop this values as we wont be able to process them.

# %%
# Clean reviews
pos_reviews = pos_reviews.dropna(subset=["cleaned_review"])
neg_reviews = neg_reviews.dropna(subset=["cleaned_review"])

# %% [markdown]
# # Applying TF-IDF

# %%
# Group reviews by game 
# This creates ONE document per game (concatenating all reviews)
grouped_pos = pos_reviews.groupby("Game")["cleaned_review"].apply(lambda x: " ".join(x)).reset_index()
grouped_neg = neg_reviews.groupby("Game")["cleaned_review"].apply(lambda x: " ".join(x)).reset_index()

# TF-IDF for positive reviews 
vectorizer_pos = TfidfVectorizer(stop_words="english", ngram_range=(1, 2), max_features=5000)
tfidf_matrix_pos = vectorizer_pos.fit_transform(grouped_pos["cleaned_review"])
terms_pos = vectorizer_pos.get_feature_names_out()
top_words_pos = tfidf_matrix_pos.toarray().argsort(axis=1)[:, -10:][:, ::-1]  # Top 10 per row

# TF-IDF for negative reviews
vectorizer_neg = TfidfVectorizer(stop_words="english", ngram_range=(1, 2), max_features=5000)
tfidf_matrix_neg = vectorizer_neg.fit_transform(grouped_neg["cleaned_review"])
terms_neg = vectorizer_neg.get_feature_names_out()
top_words_neg = tfidf_matrix_neg.toarray().argsort(axis=1)[:, -10:][:, ::-1]

# Convert to lists of top terms
top_pos_words = [[terms_pos[i] for i in row] for row in top_words_pos]
top_neg_words = [[terms_neg[i] for i in row] for row in top_words_neg]

df_top_words = pd.DataFrame({
    "Game": grouped_pos["Game"],
    "Top_Positive_Words": top_pos_words
}).merge(
    pd.DataFrame({
        "Game": grouped_neg["Game"],
        "Top_Negative_Words": top_neg_words
    }),
    on="Game",
    how="outer"
)

df_top_words.to_csv("game_top_tfidf_words_by_doc.csv", index=False)
df_top_words.head()
# Out:
#                                     Game  \
# 0                                  0 Day
# 1                      100% Orange Juice
# 2                 ARK: Survival Ascended
# 3                  ARK: Survival Evolved
# 4  Age of Empires II: Definitive Edition
#
#                                   Top_Positive_Words  \
# 0  [devs love, game wait, devs, wait, love game, ...
# 1  [dice, mario party, juice, game, mario, orange...
# 2  [game, ark, ascend, play, good, like, server, ...
# 3  [game, dinosaur, play, good, fun, dino, ark, t...
# 4  [game, rt, good, play, aoe, good rt, classic, ...
#
#                                   Top_Negative_Words
# 0                                                NaN
# 1  [dream hell, highpitche continuous, shorter an...
# 2  [game, ark, ase, wildcard, server, survival, e...
# 3  [game, play, server, ark, time, like, dino, wi...
# 4  [game, unit, civilization, internet, play, bug...

# %% [markdown]
# Our method seems to have work, however we want to explore more the values we are getting for each game

# %%
for index, row in df_top_words.iterrows():
    print(f"{row['Game']} - Positive Words: {row['Top_Positive_Words']}")
# Out:
# 0 Day - Positive Words: ['devs love', 'game wait', 'devs', 'wait', 'love game', 'love', 'game', 'game balance', 'game age', 'game add']
# 100% Orange Juice - Positive Words: ['dice', 'mario party', 'juice', 'game', 'mario', 'orange juice', 'roll', 'dice roll', 'rng', 'party']
# ARK: Survival Ascended - Positive Words: ['game', 'ark', 'ascend', 'play', 'good', 'like', 'server', 'mod', 'dinosaur', 'time']
# ARK: Survival Evolved - Positive Words: ['game', 'dinosaur', 'play', 'good', 'fun', 'dino', 'ark', 'tame', 'like', 'server']
# Age of Empires II: Definitive Edition - Positive Words: ['game', 'rt', 'good', 'play', 'aoe', 'good rt', 'classic', 'strategy', 'strategy game', 'definitive edition']
# Age of Empires IV: Anniversary Edition - Positive Words: ['game', 'age empire', 'aoe', 'rt', 'empire', 'good', 'play', 'age', 'civilization', 'civ']
# Artifact - Positive Words: ['valve', 'murder', 'great game', 'great', 'game', 'zone', 'game amazing', 'game addictive', 'game age', 'game allow']
# Assassin's Creed® Origins - Positive Words: ['ac', 'game', 'egypt', 'ac game', 'assassin', 'creed', 'bayek', 'good', 'origin', 'ancient egypt']
# Atomic Heart - Positive Words: ['game', 'bioshock', 'atomic heart', 'atomic', 'good', 'story', 'soviet', 'like', 'fun', 'great']
# BONEWORKS - Positive Words: ['bonework', 'game', 'bonelab', 'vr', 'sandbox love', 'love sandbox', 'good', 'vr game', 'sandbox', 'story']
# Baldur's Gate 3 - Positive Words: ['game', 'play', 'larian', 'dnd', 'character', 'story', 'good', 'baldur', 'gate', 'baldur gate']
# Barotrauma - Positive Words: ['game', 'submarine', 'barotrauma', 'ship', 'friend', 'good', 'play', 'crew', 'sub', 'clown']
# Battlefield 4™ - Positive Words: ['battlefield', 'game', 'good', 'campaign', 'battlefield game', 'play', 'like', 'good battlefield', 'server', 'time']
# Battlefield™ 2042 - Positive Words: ['battlefield', 'game', 'good', 'battlefield game', 'fun', 'like', 'play', 'bf', 'launch', 'operator']
# Beast Saga - Positive Words: ['zone', 'game bad', 'game age', 'game allow', 'game alot', 'game alright', 'game amazing', 'game anymore', 'game awesome', 'game balance']
# Beat Saber - Positive Words: ['vr', 'beat saber', 'game', 'saber', 'song', 'vr game', 'beat', 'play', 'good', 'rhythm']
# Black Squad - Positive Words: ['beste', 'sehr', 'csgo', 'free play', 'game', 'viel', 'ein', 'nur', 'play fps', 'founder']
# Box Cat Bash - Positive Words: ['pay like', 'fun kind', 'buy friend', 'play beautiful', 'bastard', 'bird', 'actual gameplay', 'sale fun', 'play minute', 'absolutely recommend']
# Brawlhalla - Positive Words: ['floaty', 'buy skin', 'like super', 'diamond', 'fun yes', 'ah', 'fight game', 'smash', 'neat', 'goofy']
# CODE VEIN - Positive Words: ['game', 'code vein', 'anime', 'vein', 'soulslike', 'code', 'soul', 'good', 'io', 'like']
# Company of Heroes 3 - Positive Words: ['game', 'coh', 'rt', 'good', 'play', 'relic', 'fun', 'great', 'campaign', 'update']
# Contra Anniversary Collection - Positive Words: ['contra', 'nes', 'konami', 'ne', 'space marine', 'collection', 'game', 'marine', 'play', 'ol']
# Cookie Clicker - Positive Words: ['pain pain', 'pain', 'cookie', 'click click', 'stop stop', 'click', 'cookie cookie', 'click cookie', 'game', 'clicker']
# Counter-Strike 2 - Positive Words: ['game', 'cheater', 'counterstrike', 'csgo', 'good', 'play', 'valve', 'player', 'fun', 'like']
# Crusader Kings III - Positive Words: ['game', 'crusader king', 'crusader', 'king', 'strategy game', 'play', 'good', 'strategy', 'like', 'pope']
# Cursed to Golf - Positive Words: ['pin', 'golf', 'game', 'golf game', 'ball pin', 'card', 'hole', 'pin help', 'drill', 'ball']
# Cyberpunk 2077 - Positive Words: ['game', 'cyberpunk', 'night city', 'story', 'play', 'phantom liberty', 'phantom', 'good', 'liberty', 'city']
# DARK SOULS™ II - Positive Words: ['soul', 'game', 'dark', 'dark soul', 'scholar', 'los', 'souls', 'la', 'soul game', 'dark souls']
# DARK SOULS™ III - Positive Words: ['game', 'boss', 'soul', 'ring', 'elden', 'elden ring', 'dark', 'dark soul', 'good', 'play']
# Darkest Dungeon® II - Positive Words: ['game', 'dark dungeon', 'dungeon', 'kingdom', 'confession', 'hero', 'darkest dungeon', 'darkest', 'token', 'like']
# Dead Cells - Positive Words: ['game', 'cell', 'dead cell', 'metroidvania', 'roguelike', 'good', 'dead', 'fun', 'play', 'like']
# Dead by Daylight - Positive Words: ['game', 'killer', 'survivor', 'play', 'fun', 'dbd', 'good', 'time', 'killer survivor', 'like']
# Deep Rock Galactic - Positive Words: ['rich rich', 'rock stone', 'rich', 'game', 'stone', 'rock', 'dwarf', 'deep rock', 'fun', 'play']
# Destiny 2 - Positive Words: ['destiny', 'game', 'bungie', 'play', 'good', 'player', 'time', 'fun', 'like', 'new']
# DiRT Rally - Positive Words: ['rally', 'game', 'car', 'dirt rally', 'rally game', 'dirt', 'race', 'good', 'paper', 'drive']
# Dota 2 - Positive Words: ['game', 'time killer', 'caution', 'free game', 'start good', 'probably play', 'game love', 'killer', 'dangerous', 'earth']
# Dying Light - Positive Words: ['zombie', 'game', 'die light', 'parkour', 'zombie game', 'good', 'light', 'good zombie', 'play', 'die']
# ELDEN RING - Positive Words: ['game', 'elden', 'elden ring', 'ring', 'die swing', 'boss', 'play', 'swing die', 'swing', 'soul']
# Elementary Anatomy: With Story Mode - Positive Words: ['ant mode', 'ant', 'mode', 'lag badly', 'anatomy', 'layer', 'badly', 'female', 'tool', 'story mode']
# Elite Dangerous - Positive Words: ['game', 'space', 'elite', 'ship', 'elite dangerous', 'play', 'space sim', 'galaxy', 'like', 'dangerous']
# Euro Truck Simulator 2 - Positive Words: ['truck', 'game', 'drive', 'truck simulator', 'trucking', 'euro truck', 'good', 'road', 'europe', 'coming fog']
# Europa Universalis IV - Positive Words: ['game', 'paradox', 'paradox game', 'conquer', 'strategy game', 'napoleon', 'play', 'empire', 'kill native', 'sack']
# Exanima - Positive Words: ['game', 'exanima', 'arena', 'combat', 'dungeon crawler', 'dungeon', 'update', 'crawler', 'fun', 'like']
# FINAL FANTASY X/X-2 HD Remaster - Positive Words: ['ha ha', 'ha', 'game', 'final fantasy', 'ffx', 'fantasy', 'story', 'play', 'good', 'final']
# Fallout 4 - Positive Words: ['fallout', 'game', 'settlement', 'fallout game', 'mod', 'good', 'play', 'vegas', 'bethesda', 'new vegas']
# Far Cry® 4 - Positive Words: ['game', 'far', 'pagan', 'good', 'story', 'kyrat', 'like', 'ubisoft', 'far game', 'fun']
# Far Cry® 5 - Positive Words: ['game', 'far', 'ubisoft', 'good', 'story', 'play', 'farcry', 'fun', 'like', 'cult']
# FragPunk - Positive Words: ['game', 'lancer', 'currency', 'fragpunk', 'card', 'play', 'valorant', 'fun', 'shooter', 'beta']
# Golf With Your Friends - Positive Words: ['golf', 'game', 'friend', 'golf friend', 'fun', 'play', 'ball', 'good', 'map', 'recommend']
# Grand Theft Auto V Legacy - Positive Words: ['game', 'gamble gamble', 'gta', 'gamble', 'online', 'good', 'play', 'story', 'fun', 'gta online']
# Keep Driving - Positive Words: ['game', 'hitchhiker', 'road', 'road trip', 'car', 'music', 'drive', 'trip', 'play', 'like']
# Kingdom Come: Deliverance II - Positive Words: ['game', 'henry', 'warhorse', 'quest', 'story', 'deliverance', 'kingdom come', 'come deliverance', 'feel', 'like']
# Lossless Scaling - Positive Words: ['frame', 'fps', 'game', 'frame generation', 'lossless', 'software', 'frame gen', 'gpu', 'program', 'generation']
# MONSTER HUNTER RISE - Positive Words: ['monster', 'monster hunter', 'hunter', 'game', 'mh', 'rise', 'good', 'sunbreak', 'world', 'play']
# Mafia: Definitive Edition - Positive Words: ['mafia', 'game', 'story', 'good', 'play', 'remake', 'car', 'definitive edition', 'like', 'feel']
# MapleStory - Positive Words: ['game', 'maplestory', 'play', 'server', 'european', 'maple', 'european server', 'time', 'come maplestory', 'play maple']
# Marvel’s Spider-Man Remastered - Positive Words: ['spiderman', 'game', 'good', 'spiderman game', 'story', 'play', 'great', 'fun', 'swinge', 'spider']
# Mass Effect™ Legendary Edition - Positive Words: ['game', 'mass effect', 'mass', 'trilogy', 'effect', 'play', 'good', 'legendary edition', 'story', 'shepard']
# Monster Hunter: World - Positive Words: ['game', 'monster', 'game love', 'love game', 'love', 'monster hunter', 'hunter', 'play', 'wild', 'hunt']
# My Time at Sandrock - Positive Words: ['portia', 'game', 'sandrock', 'time portia', 'time', 'story', 'time sandrock', 'character', 'like', 'good']
# NBA 2K25 - Positive Words: ['game', 'basketball', 'nba', 'play', 'good', 'like', 'vc', 'fun', 'player', 'great']
# No Man's Sky - Positive Words: ['game', 'planet', 'space', 'play', 'hello game', 'exploration', 'mans sky', 'good', 'like', 'hello']
# PAYDAY 2 - Positive Words: ['payday', 'game', 'heist', 'play', 'good', 'fun', 'bank', 'medic', 'bag', 'drill']
# PUBG: BATTLEGROUNDS - Positive Words: ['game', 'pubg', 'good', 'br', 'battle royale', 'royale', 'fun', 'play', 'battle', 'good game']
# Pathfinder: Kingmaker — Enhanced Plus Edition - Positive Words: ['pathfinder', 'game', 'owlcat', 'kingdom management', 'crpgs', 'kingmaker', 'kingdom', 'crpg', 'time', 'rpg']
# Phasmophobia - Positive Words: ['game', 'ghost', 'fun', 'play', 'friend', 'scary', 'horror', 'good', 'play friend', 'mimic mimic']
# Planet Coaster - Positive Words: ['coaster', 'game', 'park', 'planet coaster', 'tycoon', 'roller coaster', 'roller', 'planet', 'guest', 'fun']
# Portal 2 - Positive Words: ['portal', 'game', 'puzzle', 'good', 'puzzle game', 'play', 'story', 'valve', 'glado', 'chamber']
# Ravenfield - Positive Words: ['game', 'mod', 'good', 'fun', 'good game', 'play', 'game mod', 'modding', 'war', 'great']
# Red Dead Redemption 2 - Positive Words: ['game', 'story', 'play', 'good', 'arthur', 'red dead', 'world', 'rockstar', 'dead redemption', 'redemption']
# Resident Evil 4 - Positive Words: ['game', 'remake', 'resident evil', 'resident', 'leon', 'evil', 'ashley', 'original', 'good', 'play']
# Robin Hood - Sherwood Builders - Positive Words: ['robin hood', 'game', 'quest', 'robin', 'village', 'like', 'quest puzzle', 'hood', 'puzzle', 'combat']
# Rust - Positive Words: ['game', 'rust', 'raid', 'play', 'server', 'good', 'fun', 'beach', 'time', 'hour']
# Satisfactory - Positive Words: ['game', 'factory', 'satisfactory', 'build', 'play', 'conveyor', 'like', 'conveyor belt', 'time', 'belt']
# Sekiro™: Shadows Die Twice - GOTY Edition - Positive Words: ['game', 'hesitation defeat', 'defeat hesitation', 'sekiro', 'hesitation', 'combat', 'defeat', 'good', 'boss', 'fromsoft']
# Shadowrun Returns - Positive Words: ['shadowrun', 'game', 'story', 'good', 'play', 'turn base', 'linear', 'tabletop', 'racial', 'like']
# Sid Meier’s Civilization® VI - Positive Words: ['civ', 'game', 'play', 'civilization', 'vi', 'good', 'fun', 'like', 'strategy game', 'strategy']
# Space Engineers - Positive Words: ['game', 'space', 'space engineer', 'ship', 'engineer', 'build', 'good', 'sandbox', 'play', 'fun']
# Split Fiction - Positive Words: ['game', 'split fiction', 'hazelight', 'play', 'fiction', 'split', 'coop', 'story', 'good', 'fun']
# Star Wars Outlaws - Positive Words: ['star war', 'game', 'war', 'star', 'like', 'war game', 'jedi', 'ubisoft', 'play', 'fun']
# Stardew Valley - Positive Words: ['game', 'stardew', 'play', 'stardew valley', 'farming', 'valley', 'cozy', 'farm', 'fun', 'love']
# Team Fortress 2 - Positive Words: ['game', 'good', 'fortress', 'play', 'love', 'slip', 'valve', 'heavy', 'feel way', 'team']
# Terraria - Positive Words: ['game', 'terraria', 'play', 'fun', 'minecraft', 'boss', 'good', 'great', 'mod', 'like']
# The Binding of Isaac: Rebirth - Positive Words: ['gambling love', 'sacce', 'love gambling', 'sacce sacce', 'isaac', 'game', 'gambling', 'love', 'bind isaac', 'play']
# The Sims™ 4 - Positive Words: ['sim', 'game', 'good', 'fun', 'play', 'love', 'like', 'life', 'ea', 'pack']
# The Survivalists - Positive Words: ['game', 'monkey', 'survivalist', 'good', 'like', 'fun', 'survival', 'ya', 'survival game', 'di']
# The Witcher 3: Wild Hunt - Positive Words: ['game', 'witcher', 'geralt', 'story', 'play', 'good', 'quest', 'gwent', 'world', 'time']
# Thief - Positive Words: ['thief', 'game', 'stealth', 'good', 'thief game', 'like', 'story', 'series', 'reboot', 'play']
# Titanfall® 2 - Positive Words: ['titanfall', 'game', 'campaign', 'titan', 'play', 'good', 'multiplayer', 'story', 'bt', 'movement']
# Tom Clancy's Rainbow Six® Siege - Positive Words: ['game', 'siege', 'play', 'good', 'fun', 'operator', 'rainbow siege', 'rainbow', 'tactical', 'shooter']
# Tower Unite - Positive Words: ['game', 'condo', 'tower', 'fun', 'play', 'tower unite', 'gmod tower', 'social', 'friend', 'minigolf']
# Unknown Game - Positive Words: ['game', 'code vein', 'anime', 'vein', 'soulslike', 'code', 'soul', 'good', 'io', 'like']
# Valheim - Positive Words: ['game', 'valheim', 'play', 'survival', 'survival game', 'biome', 'good', 'like', 'world', 'vike']
# Warhammer 40,000: Space Marine 2 - Positive Words: ['game', 'marine', 'space marine', 'warhammer', 'emperor', 'campaign', 'play', 'operation', 'good', 'fun']
# Windblown - Positive Words: ['game', 'dead cell', 'cell', 'play', 'windblown', 'early access', 'fun', 'hade', 'roguelike', 'dead']
# X-Morph: Defense - Positive Words: ['tower defense', 'defense', 'tower', 'turret', 'game', 'anti air', 'wave', 'plasma', 'anti', 'attack']
# Yakuza 0 - Positive Words: ['yakuza', 'game', 'kiryu', 'majima', 'story', 'good', 'play', 'series', 'time', 'like']

# %%
for index, row in df_top_words.iterrows():
    print(f"{row['Game']} - Negative Words: {row['Top_Negative_Words']}")
# Out:
# 0 Day - Negative Words: nan
# 100% Orange Juice - Negative Words: ['dream hell', 'highpitche continuous', 'shorter annoying', 'moaning', 'moaning ear', 'ladder instead', 'hear highpitche', 'work hear', 'play number', 'highpitche']
# ARK: Survival Ascended - Negative Words: ['game', 'ark', 'ase', 'wildcard', 'server', 'survival', 'evolve', 'play', 'crash', 'ark survival']
# ARK: Survival Evolved - Negative Words: ['game', 'play', 'server', 'ark', 'time', 'like', 'dino', 'wildcard', 'fun', 'snail']
# Age of Empires II: Definitive Edition - Negative Words: ['game', 'unit', 'civilization', 'internet', 'play', 'bug', 'time', 'new', 'connection', 'delete game']
# Age of Empires IV: Anniversary Edition - Negative Words: ['game', 'aoe', 'empire', 'play', 'age', 'like', 'player', 'skilled', 'historical', 'opponent']
# Artifact - Negative Words: nan
# Assassin's Creed® Origins - Negative Words: ['ubisoft', 'game', 'connect', 'ubisoft connect', 'play', 'quest', 'ac', 'open world', 'pretty', 'open']
# Atomic Heart - Negative Words: ['game', 'robot', 'atomic', 'like', 'atomic heart', 'bioshock', 'whine', 'bok', 'bot', 'dialogue']
# BONEWORKS - Negative Words: ['puzzle', 'son', 'story mode', 'hat', 'run bad', 'afterthought', 'unintereste', 'time start', 'game', 'force']
# Baldur's Gate 3 - Negative Words: ['character', 'gear', 'character creation', 'companion', 'pause', 'creation', 'cap', 'level', 'way', 'useful']
# Barotrauma - Negative Words: ['ship', 'game', 'pet', 'sub', 'play', 'round', 'casual', 'game skill', 'husk', 'item']
# Battlefield 4™ - Negative Words: ['punkbuster', 'game', 'server', 'kick', 'kick punkbuster', 'play', 'ea', 'campaign', 'multiplayer', 'ddose']
# Battlefield™ 2042 - Negative Words: ['game', 'battlefield', 'ea', 'play', 'bf', 'bad', 'like', 'time', 'good', 'buy']
# Beast Saga - Negative Words: nan
# Beat Saber - Negative Words: ['song', 'game', 'steamvr', 'rhythm', 'saber', 'play', 'issue', 'expert', 'mod', 'major issue']
# Black Squad - Negative Words: ['game', 'clan', 'valofe', 'founder package', 'founder', 'waist time', 'black squad', 'money', 'chat', 'waist']
# Box Cat Bash - Negative Words: nan
# Brawlhalla - Negative Words: ['bs bad', 'price package', 'brawler offering', 'package sure', 'debut kind', 'debut', 'try straight', 'bad thumb', 'ea debut', 'mid brawler']
# CODE VEIN - Negative Words: ['game', 'soul', 'dark soul', 'soulslike', 'dark', 'like', 'enemy', 'code vein', 'stamina', 'design']
# Company of Heroes 3 - Negative Words: ['game', 'unit', 'relic', 'coh', 'battlegroup', 'tank', 'faction', 'like', 'play', 'company hero']
# Contra Anniversary Collection - Negative Words: ['port', 'away egregious', 'topic contra', 'egregious progression', 'purely topic', 'away emulator', 'focusse', 'industry far', 'masochist enjoy', 'keymappe']
# Cookie Clicker - Negative Words: ['cookie', 'game', 'addict', 'play', 'ascend', 'life', 'progress', 'team', 'achievement', 'placement']
# Counter-Strike 2 - Negative Words: ['cheater', 'game', 'vac', 'valve', 'pls vac', 'vac pls', 'pls', 'play', 'counterstrike', 'csgo']
# Crusader Kings III - Negative Words: ['game', 'paradox', 'dlc', 'kingdom', 'unit', 'dlcs', 'doo', 'game worst', 'worst', 'lose']
# Cursed to Golf - Negative Words: ['golf', 'card', 'game', 'golf game', 'stroke', 'use', 'ball', 'hole', 'roguelike', 'arrow']
# Cyberpunk 2077 - Negative Words: nan
# DARK SOULS™ II - Negative Words: ['scholar', 'game', 'sotfs', 'soul', 'play', 'original', 'dark soul', 'enemy placement', 'soul game', 'vanilla']
# DARK SOULS™ III - Negative Words: ['game', 'soul', 'dark soul', 'dark', 'boss', 'play', 'elden', 'elden ring', 'attack', 'soul game']
# Darkest Dungeon® II - Negative Words: ['game', 'boss', 'character', 'run', 'dungeon', 'hero', 'dark dungeon', 'like', 'time', 'attack']
# Dead Cells - Negative Words: ['game', 'roguelike', 'dead cell', 'cell', 'rogue', 'dead', 'like', 'exploration', 'dlc', 'atmosphere']
# Dead by Daylight - Negative Words: ['killer', 'survivor', 'game', 'perk', 'play', 'fun', 'hook', 'player', 'dbd', 'killer survivor']
# Deep Rock Galactic - Negative Words: ['game', 'play', 'like', 'rock', 'mission', 'feel', 'good', 'perk', 'upgrade', 'heavily']
# Destiny 2 - Negative Words: ['destiny', 'game', 'bungie', 'content', 'player', 'play', 'new', 'season', 'story', 'new player']
# DiRT Rally - Negative Words: nan
# Dota 2 - Negative Words: ['game', 'ew', 'river ocean', 'toxic auto', 'auto loss', 'loss troll', 'play nerd', 'troll exist', 'exist hear', 'nerd ew']
# Dying Light - Negative Words: ['game', 'zombie', 'die light', 'play', 'weapon', 'run', 'light', 'story', 'die', 'mission']
# ELDEN RING - Negative Words: nan
# Elementary Anatomy: With Story Mode - Negative Words: ['clumsy unpolished', 'interface extremely', 'extremely clumsy', 'work interface', 'unpolished work', 'work controller', 'clumsy', 'unpolished', 'controller work', 'interface']
# Elite Dangerous - Negative Words: ['ship', 'game', 'planet', 'space', 'mission', 'elite', 'like', 'frontier', 'time', 'fly']
# Euro Truck Simulator 2 - Negative Words: ['game', 'truck', 'cargo', 'play', 'update', 'time', 'change', 'layout', 'developer', 'like']
# Europa Universalis IV - Negative Words: ['game', 'nation', 'paradox', 'strategy game', 'strategy', 'people dlcs', 'dlcs', 'dlc', 'loan', 'dlc policy']
# Exanima - Negative Words: ['game', 'year', 'early access', 'tech demo', 'demo', 'tech', 'access', 'exanima', 'early', 'devs']
# FINAL FANTASY X/X-2 HD Remaster - Negative Words: ['game', 'final fantasy', 'fantasy', 'scene', 'cut scene', 'final', 'cut', 'play', 'green', 'crash']
# Fallout 4 - Negative Words: ['game', 'fallout', 'bethesda', 'mod', 'play', 'update', 'time', 'crash', 'load', 'load time']
# Far Cry® 4 - Negative Words: ['game', 'ubisoft', 'gyro', 'play', 'launcher', 'uplay', 'stall', 'far', 'unskippable', 'mission']
# Far Cry® 5 - Negative Words: ['ubisoft', 'game', 'play', 'story', 'time', 'cult', 'like', 'far', 'ubisoft connect', 'mission']
# FragPunk - Negative Words: ['game', 'currency', 'beta', 'lancer', 'gacha', 'like', 'monetization', 'movement', 'feel', 'play']
# Golf With Your Friends - Negative Words: ['golf', 'game', 'hole', 'map', 'play', 'lobby', 'achievement', 'ball', 'friend', 'shot']
# Grand Theft Auto V Legacy - Negative Words: ['rockstar', 'game', 'gta', 'online', 'gta online', 'play', 'linux', 'mission', 'anticheat', 'player']
# Keep Driving - Negative Words: ['game', 'cash', 'road', 'drive', 'event', 'buck', 'car', 'like', 'need', 'feel']
# Kingdom Come: Deliverance II - Negative Words: ['medieval', 'game', 'quest', 'like', 'feel', 'time', 'choice', 'guard', 'sword', 'hour']
# Lossless Scaling - Negative Words: ['lossless', 'frame', 'fps', 'scaling', 'game', 'work', 'scale', 'monitor', 'el', 'program']
# MONSTER HUNTER RISE - Negative Words: ['risen', 'investigation risen', 'magala risen', 'magala', 'shagaru magala', 'valstrax', 'glow valstrax', 'risen shagaru', 'anomaly investigation', 'shagaru']
# Mafia: Definitive Edition - Negative Words: ['game', 'mafia', 'race', 'play', 'fullscreen', 'like', 'feel', 'story', 'drive', 'car']
# MapleStory - Negative Words: ['game', 'new', 'kill thing', 'nexon', 'lest', 'play', 'thing', 'server', 'hour', 'time']
# Marvel’s Spider-Man Remastered - Negative Words: ['game', 'play', 'repetitive', 'boss', 'boring', 'ugly', 'like', 'time', 'main', 'feel']
# Mass Effect™ Legendary Edition - Negative Words: ['ea', 'game', 'mass effect', 'mass', 'play', 'app', 'effect', 'ea app', 'squad', 'launcher']
# Monster Hunter: World - Negative Words: ['monster', 'game', 'hunter', 'monster hunter', 'play', 'feel', 'like', 'weapon', 'wild', 'attack']
# My Time at Sandrock - Negative Words: ['game', 'sandrock', 'multiplayer', 'play', 'story', 'lvl', 'play version', 'cross', 'buddy', 'time']
# NBA 2K25 - Negative Words: ['game', 'foul', 'reach foul', 'foul reach', 'nba', 'basketball', 'play', 'reach', 'vc', 'player']
# No Man's Sky - Negative Words: ['game', 'planet', 'mans', 'sky', 'ship', 'base', 'like', 'bug', 'thing', 'time']
# PAYDAY 2 - Negative Words: ['game', 'heist', 'gibi', 'dlc', 'rob', 'dislike', 'stealth', 'buy dlc', 'time', 'dlcs']
# PUBG: BATTLEGROUNDS - Negative Words: ['game', 'cheater', 'play', 'pubg', 'hacker', 'ban', 'cheat', 'chinese', 'server', 'bot']
# Pathfinder: Kingmaker — Enhanced Plus Edition - Negative Words: ['pathfinder', 'game', 'encounter', 'spider', 'kingmaker', 'play pathfinder', 'ttrpg', 'party', 'kingdom', 'kingdom management']
# Phasmophobia - Negative Words: ['game', 'ghost', 'rework', 'map', 'like', 'update', 'new', 'community', 'new map', 'year']
# Planet Coaster - Negative Words: ['coaster', 'park', 'game', 'roof', 'planet', 'building', 'build', 'ride', 'feel', 'snap']
# Portal 2 - Negative Words: ['portal', 'puzzle', 'game', 'wall', 'white', 'clearly', 'game puzzle', 'manipulate', 'kinda', 'spray']
# Ravenfield - Negative Words: ['game', 'year', 'modding', 'mod', 'modder', 'promise', 'developer', 'early access', 'finish', 'mode']
# Red Dead Redemption 2 - Negative Words: nan
# Resident Evil 4 - Negative Words: ['game', 'good', 'original', 'evil', 'knife', 'play', 'boss', 'like', 'remake', 'horror']
# Robin Hood - Sherwood Builders - Negative Words: ['game', 'robin', 'unfinished tech', 'tech demo', 'english', 'feel', 'demo', 'unfinished', 'tech', 'like']
# Rust - Negative Words: ['game', 'rust', 'server', 'ban', 'play', 'time', 'cheater', 'like', 'player', 'survival']
# Satisfactory - Negative Words: ['game', 'item', 'build', 'blueprint', 'need', 'train', 'factory', 'station', 'like', 'building']
# Sekiro™: Shadows Die Twice - GOTY Edition - Negative Words: ['game', 'boss', 'like', 'parry', 'soul', 'time', 'block', 'camera', 'attack', 'controller']
# Shadowrun Returns - Negative Words: ['sequel', 'miss', 'ending feel', 'buggy mean', 'like hate', 'game unbalance', 'missing', 'soft', 'fight game', 'pretty great']
# Sid Meier’s Civilization® VI - Negative Words: ['civ', 'game', 'play', 'ai', 'city', 'like', 'time', 'era', 'crash', 'civilization']
# Space Engineers - Negative Words: ['game', 'space engineer', 'engineer', 'space', 'dlcs', 'ship', 'scenario', 'build', 'like', 'play']
# Split Fiction - Negative Words: ['game', 'story', 'character', 'split', 'datum', 'feel', 'world', 'play', 'ea', 'user']
# Star Wars Outlaws - Negative Words: ['game', 'star war', 'ubisoft', 'star', 'war', 'play', 'like', 'feel', 'story', 'crash']
# Stardew Valley - Negative Words: ['task manager', 'manager', 'deck', 'steam deck', 'game far', 'task', 'report', 'xbox', 'patch', 'console']
# Team Fortress 2 - Negative Words: ['valve', 'game', 'bot', 'play', 'view', 'year', 'community', 'time', 'competitive', 'good']
# Terraria - Negative Words: ['que', 'jogo', 'da', 'se', 'na', 'boss', 'real', 'devs', 'leave', 'design']
# The Binding of Isaac: Rebirth - Negative Words: ['isaac', 'game', 'item', 'like', 'time', 'feel', 'good', 'play', 'enemy', 'boss']
# The Sims™ 4 - Negative Words: ['sim', 'game', 'dlc', 'ea', 'sims', 'pack', 'play', 'content', 'base game', 'want']
# The Survivalists - Negative Words: ['game', 'monkey', 'like', 'play', 'blueprint', 'bugsmonkey', 'multiplayr', 'monkeyscant', 'monkeyscant craft', 'tell host']
# The Witcher 3: Wild Hunt - Negative Words: ['game', 'witcher', 'like', 'play', 'combat', 'feel', 'good', 'control', 'loot', 'world']
# Thief - Negative Words: ['game', 'thief', 'stealth', 'open', 'playstyle', 'story', 'open world', 'pretty', 'feel', 'play']
# Titanfall® 2 - Negative Words: ['game', 'ea', 'campaign', 'play', 'time', 'fuck', 'like', 'play campaign', 'learn', 'launcher']
# Tom Clancy's Rainbow Six® Siege - Negative Words: ['game', 'buy buy', 'ubisoft', 'play', 'buy', 'siege', 'bad', 'player', 'cheater', 'ban']
# Tower Unite - Negative Words: ['game', 'server', 'figure way', 'coast', 'bowl', 'absolutely love', 'road', 'price game', 'like', 'issue']
# Unknown Game - Negative Words: ['game', 'soul', 'dark soul', 'soulslike', 'dark', 'like', 'enemy', 'code vein', 'stamina', 'design']
# Valheim - Negative Words: ['game', 'biome', 'boss', 'ashland', 'valheim', 'time', 'mistland', 'new', 'play', 'like']
# Warhammer 40,000: Space Marine 2 - Negative Words: ['game', 'marine', 'space marine', 'play', 'campaign', 'operation', 'pvp', 'mission', 'weapon', 'like']
# Windblown - Negative Words: ['dead cell', 'cell', 'motion twin', 'dead', 'twin', 'game', 'melee', 'motion', 'content', 'weapon']
# X-Morph: Defense - Negative Words: ['default screen', 'screen', 'default', 'set', 'set game', 'boring quickly', 'play screen', 'game set', 'game', 'andor']
# Yakuza 0 - Negative Words: ['game', 'chapter', 'story', 'dig', 'reason', 'combat', 'unplayable', 'fight', 'pc', 'fuck']

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Select a game for visualization
selected_game = "The Witcher 3: Wild Hunt"  

# Extract positive and negative words for the selected game
game_data = df_top_words[df_top_words["Game"] == selected_game]

if not game_data.empty:
    pos_words = game_data["Top_Positive_Words"].values[0]
    neg_words = game_data["Top_Negative_Words"].values[0]

    # Convert lists to space-separated strings
    pos_text = " ".join(pos_words)
    neg_text = " ".join(neg_words)

    # Create figure for side-by-side word clouds
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))

    # Generate Positive Word Cloud
    wordcloud_pos = WordCloud(width=500, height=500, background_color="white").generate(pos_text)
    axes[0].imshow(wordcloud_pos, interpolation="bilinear")
    axes[0].axis("off")
    axes[0].set_title(f"Positive Reviews - {selected_game}", fontsize=14)

    # Generate Negative Word Cloud
    wordcloud_neg = WordCloud(width=500, height=500, background_color="black", colormap="Reds").generate(neg_text)
    axes[1].imshow(wordcloud_neg, interpolation="bilinear")
    axes[1].axis("off")
    axes[1].set_title(f"Negative Reviews - {selected_game}", fontsize=14)

    # Show the word clouds
    plt.show()
else:
    print(f"No data found for {selected_game}")

# %% [markdown]
# There is something clear in this approach, "game" is appearing in many games. Allthough TF-IDF should be downweighting this word, it might be frequent in most documents but still slightly more frequent in some, making its TF-IDF not low enough. We need to handle this, words like "game", "good", "play", "great", "bad" that doesnt really say nothing to us, therefore we have to add them to a stopword list to remove them. Further more words like Witcher that involve the own title of the game are not meaningfull so we need to remove this as well.

# %% [markdown]
# # Enhancing our process

# %%
custom_stopwords = {
    "ve", "re", "want", "try", "new", "work", "need", "thing", "buy", "fix", 
    "hour", "long", "gameplay", "update", "dlc", "player", "pay",
    'time', 'game', 'play', 'good', 'great', 'bad', 'like', 'fun', 
    'best', 'better', 'enjoy', 'recommend', 'yes', "feel", "lot", "come", "way", "nice", "ha", "think",
    "aight", "haha", "gobagool", "goate", "unsuur", "jyjtyjtukutk"
}

def remove_custom_stopwords(text):
    tokens = text.split()
    filtered = [t for t in tokens if t.lower() not in custom_stopwords]
    return " ".join(filtered)



def remove_game_name_words(df):
    cleaned = []
    for _, row in df.iterrows():
        game = row["Game"]
        text = row["cleaned_review"]
        # Lowercase + split game name into words
        game_words = re.findall(r"\b\w+\b", game.lower())
        tokens = text.split()
        filtered = [t for t in tokens if t.lower() not in game_words]
        cleaned.append(" ".join(filtered))
    df["cleaned_review"] = cleaned
    return df


# Clean reviews
pos_reviews = pos_reviews.dropna(subset=["cleaned_review"])
neg_reviews = neg_reviews.dropna(subset=["cleaned_review"])

pos_reviews["cleaned_review"] = pos_reviews["cleaned_review"].apply(remove_custom_stopwords)
neg_reviews["cleaned_review"] = neg_reviews["cleaned_review"].apply(remove_custom_stopwords)
pos_reviews = remove_game_name_words(pos_reviews)
neg_reviews = remove_game_name_words(neg_reviews)

# This creates ONE document per game (concatenating all reviews)
grouped_pos = pos_reviews.groupby("Game")["cleaned_review"].apply(lambda x: " ".join(x)).reset_index()
grouped_neg = neg_reviews.groupby("Game")["cleaned_review"].apply(lambda x: " ".join(x)).reset_index()

vectorizer_pos = TfidfVectorizer(stop_words="english", ngram_range=(1, 2), max_features=5000)
tfidf_matrix_pos = vectorizer_pos.fit_transform(grouped_pos["cleaned_review"])
terms_pos = vectorizer_pos.get_feature_names_out()
top_words_pos = tfidf_matrix_pos.toarray().argsort(axis=1)[:, -10:][:, ::-1]  # Top 10 per row

vectorizer_neg = TfidfVectorizer(stop_words="english", ngram_range=(1, 2), max_features=5000)
tfidf_matrix_neg = vectorizer_neg.fit_transform(grouped_neg["cleaned_review"])
terms_neg = vectorizer_neg.get_feature_names_out()
top_words_neg = tfidf_matrix_neg.toarray().argsort(axis=1)[:, -10:][:, ::-1]

# Convert to lists of top terms
top_pos_words = [[terms_pos[i] for i in row] for row in top_words_pos]
top_neg_words = [[terms_neg[i] for i in row] for row in top_words_neg]

df_top_words = pd.DataFrame({
    "Game": grouped_pos["Game"],
    "Top_Positive_Words": top_pos_words
}).merge(
    pd.DataFrame({
        "Game": grouped_neg["Game"],
        "Top_Negative_Words": top_neg_words
    }),
    on="Game",
    how="outer"
)

df_top_words.to_csv("game_top_tfidf_words_by_doc.csv", index=False)
df_top_words.head()
# Out:
#                                     Game  \
# 0                                  0 Day
# 1                      100% Orange Juice
# 2                 ARK: Survival Ascended
# 3                  ARK: Survival Evolved
# 4  Age of Empires II: Definitive Edition
#
#                                   Top_Positive_Words  \
# 0  [wait devs, love wait, devs love, devs, wait, ...
# 1  [dice, mario party, mario, roll, dice roll, rn...
# 2  [ascend, server, mod, dinosaur, pc, graphic, d...
# 3  [dinosaur, dino, tame, asa, server, ascend, fr...
# 4  [rt, aoe, classic, strategy, empire, campaign,...
#
#                                   Top_Negative_Words
# 0                                                NaN
# 1  [ear dream, shorter annoying, chute, chute lad...
# 2  [ase, wildcard, server, evolve, crash, gb, asc...
# 3  [server, dino, wildcard, snail, dinosaur, cras...
# 4  [unit, civilization, internet, bug, compatibil...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Select a game for visualization
selected_game = "The Witcher 3: Wild Hunt"  # Change this to any game you want

# Extract positive and negative words for the selected game
game_data = df_top_words[df_top_words["Game"] == selected_game]

if not game_data.empty:
    pos_words = game_data["Top_Positive_Words"].values[0]
    neg_words = game_data["Top_Negative_Words"].values[0]

    # Convert lists to space-separated strings
    pos_text = " ".join(pos_words)
    neg_text = " ".join(neg_words)

    # Create figure for side-by-side word clouds
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))

    # Generate Positive Word Cloud
    wordcloud_pos = WordCloud(width=500, height=500, background_color="white").generate(pos_text)
    axes[0].imshow(wordcloud_pos, interpolation="bilinear")
    axes[0].axis("off")
    axes[0].set_title(f"Positive Reviews - {selected_game}", fontsize=14)

    # Generate Negative Word Cloud
    wordcloud_neg = WordCloud(width=500, height=500, background_color="black", colormap="Reds").generate(neg_text)
    axes[1].imshow(wordcloud_neg, interpolation="bilinear")
    axes[1].axis("off")
    axes[1].set_title(f"Negative Reviews - {selected_game}", fontsize=14)

    # Show the word clouds
    plt.show()
else:
    print(f"No data found for {selected_game}")

# %% [markdown]
# This looks way better, highlighting words like story, character, quest, monster, and in the negative side, loot, control or movement. We still see some repeated words such as combat, however we adress this to the fact that not everyone likes a game with combat, maybe people look for something more relaxing, so this word can be either a positive or a negative attribute depending on the user's preferences.

# %% [markdown]
# # Creating User Profile

# %% [markdown]
# To create a user profile, we decided to write some reviews ourselves. This decision was primarily driven by the need for a user with multiple reviews in our dataset. However, since we were only able to scrape a limited amount of data, collecting enough real reviews proved challenging. Our hardware limitations made it unfeasible to store every single review for every game on Steam. This issue, however, could be easily addressed with access to a more powerful computer.

# %%
# Creating a DataFrame with extended user reviews
user_reviews = pd.DataFrame({
    "Game": [
        "The Witcher 3: Wild Hunt", 
        "Dark Souls 3", 
        "X-Morph: Defense", 
        "Cyberpunk 2077", 
        "Horizon Zero Dawn",
        "Assassin’s Creed Valhalla"
    ],
    "review": [
        "I really enjoyed The Witcher 3 because of its vast open world, deep story, and breathtaking graphics. The game offers an immersive experience with well-developed characters and rich lore. The combat mechanics feel smooth, and there are countless side quests that add depth to the world. However, it required a very strong PC, and I experienced frequent crashes, which sometimes ruined the immersion.",
        
        "Dark Souls 3 was an amazing experience. The quest design is intricate, and the story, though subtle, is deeply engaging for those who invest time in understanding the lore. The combat is extremely challenging but rewarding, requiring precision and strategy. The boss fights are intense and satisfying, though some of them felt repetitive. Additionally, certain difficulty spikes felt unbalanced, making progression frustrating at times.",
        
        "I did not like X-Morph: Defense because it's a tower defense game, and I’m not into that genre. The game lacks a compelling story, and the graphics felt outdated compared to modern strategy games. The gameplay quickly became repetitive, and there wasn't much variety in the mechanics. It didn’t hold my interest for long, and I found myself getting bored after a few levels.",
        
        "Cyberpunk 2077 had a lot of potential with its futuristic open world and deep RPG mechanics. The city felt alive with plenty of characters and side quests. However, the game was plagued with technical issues, including game-breaking bugs, crashes, and unoptimized performance. While the main story was engaging, the overall experience was disappointing due to the lack of polish at launch.",
        
        "Horizon Zero Dawn was an incredible game with a unique blend of open-world exploration, a strong protagonist, and a compelling sci-fi story. The combat felt dynamic, and the world was beautifully crafted with breathtaking landscapes. The enemy AI was intelligent, and each fight required strategy. The only downside was that some side missions felt repetitive after a while, but overall, it was an amazing experience.",
        
        "Assassin’s Creed Valhalla was an enjoyable game for the most part. The Viking setting was immersive, and the world was rich with details. The combat felt weighty, and there were plenty of things to do. However, I found the progression system to be too grindy, and the game felt repetitive after some time. The story, while engaging at first, started to lose its impact halfway through. The overall experience was decent but not exceptional."
    ],
    "recommended": [
        "True", 
        "True", 
        "False", 
        "False", 
        "True", 
        "False"
    ]
})
game_metadata = pd.DataFrame({
    "Game": ["The Witcher 3: Wild Hunt", "Dark Souls 3", "X-Morph: Defense", "Cyberpunk 2077", "Horizon Zero Dawn", "Assassin’s Creed Valhalla"],
    "genre": ["RPG, Open World", "Action, RPG", "Strategy, Tower Defense", "Action, RPG, Open World", "Action, Adventure", "Action, RPG"],
    "action": [False, True, False, True, True, True],
    "strategy": [False, False, True, False, False, False],
    "free_to_play": [False, False, False, False, False, False],
    "adventure": [True, False, False, True, True, True],
    "massively_multiplayer": [False, False, False, False, False, False],
    "indie": [False, False, False, False, False, False],
    "rpg": [True, True, False, True, True, True],
    "casual": [False, False, False, False, False, False],
    "racing": [False, False, False, False, False, False],
    "early_access": [False, False, False, False, False, False],
    "simulation": [False, False, False, False, False, False],
    "unknown_genre": [False, False, False, False, False, False],
    "sports": [False, False, False, False, False, False],
    "violent": [True, True, False, True, False, True],
    "education": [False, False, False, False, False, False],
    "utilities": [False, False, False, False, False, False]
})
user_reviews = user_reviews.merge(game_metadata, on="Game", how="left")

# Display the DataFrame
print(user_reviews)
# Out:
#                         Game  \
# 0   The Witcher 3: Wild Hunt
# 1               Dark Souls 3
# 2           X-Morph: Defense
# 3             Cyberpunk 2077
# 4          Horizon Zero Dawn
# 5  Assassin’s Creed Valhalla
#
#                                               review recommended  \
# 0  I really enjoyed The Witcher 3 because of its ...        True
# 1  Dark Souls 3 was an amazing experience. The qu...        True
# 2  I did not like X-Morph: Defense because it's a...       False
# 3  Cyberpunk 2077 had a lot of potential with its...       False
# 4  Horizon Zero Dawn was an incredible game with ...        True
# 5  Assassin’s Creed Valhalla was an enjoyable gam...       False
#
#                      genre  action  strategy  free_to_play  adventure  \
# 0          RPG, Open World   False     False         False       True
# 1              Action, RPG    True     False         False      False
# 2  Strategy, Tower Defense   False      True         False      False
# 3  Action, RPG, Open World    True     False         False       True
# 4        Action, Adventure    True     False         False       True
# 5              Action, RPG    True     False         False       True
#
#    massively_multiplayer  indie    rpg  casual  racing  early_access  \
# 0                  False  False   True   False   False         False
# 1                  False  False   True   False   False         False
# 2                  False  False  False   False   False         False
# 3                  False  False   True   False   False         False
# 4                  False  False   True   False   False         False
# 5                  False  False   True   False   False         False
#
#    simulation  unknown_genre  sports  violent  education  utilities
# 0       False          False   False     True      False      False
# 1       False          False   False     True      False      False
# 2       False          False   False    False      False      False
# 3       False          False   False     True      False      False
# 4       False          False   False    False      False      False
# 5       False          False   False     True      False      False

# %% [markdown]
# In the following lines we will preprocess the user's reviews the same way we did it with all the other reviews.

# %%
import os
import re
import csv
import sys
import subprocess
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, SnowballStemmer, PorterStemmer
from nltk.corpus import stopwords
import spacy
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer, TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from tqdm import tqdm

from scipy.stats import pearsonr

# Function to download NLTK resources
def download_nltk_resources():
    required_resources = ['wordnet', 'stopwords', 'punkt']
    for resource in required_resources:
        try:
            nltk.data.find(f'tokenizers/{resource}' if resource == 'punkt' else f'corpora/{resource}')
        except LookupError:
            nltk.download(resource)

download_nltk_resources()

# Function to install and load spaCy model
def install_spacy_model(model_name):
    try:
        return spacy.load(model_name)
    except OSError:
        print(f"Downloading spaCy model: {model_name}")
        subprocess.check_call([sys.executable, "-m", "spacy", "download", model_name])
        return spacy.load(model_name)

sp = install_spacy_model('en_core_web_sm')

# Enable tqdm for pandas
tqdm.pandas()

# Initialize stemmers and lemmatizer
porter = SnowballStemmer("english")
lmtzr = WordNetLemmatizer()
STOP_WORDS = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package wordnet to /Users/gergoar/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def preprocess_lower(text):
    """
    Preprocess text by:
       - Converting to lowercase.
       - Removing punctuation.
       - Tokenizing.
       - Removing stopwords.
    
    Returns:
        str: A string of filtered tokens separated by spaces.
    """
    text_lower = text.lower()
    text_no_punct = re.sub(r'[^\w\s]', '', text_lower)
    tokens = word_tokenize(text_no_punct)
    filtered_tokens = [token for token in tokens if token not in STOP_WORDS]
    return " ".join(filtered_tokens)

def preprocess_stem(text):
    """
    Preprocess text by performing all steps in preprocess_lower() and then applying stemming.
    
    Returns:
        str: A string of stemmed tokens separated by spaces.
    """
    tokens = preprocess_lower(text).split()
    ps = PorterStemmer()
    stemmed_tokens = [ps.stem(token) for token in tokens]
    return " ".join(stemmed_tokens)


# Function to remove emojis and special characters
def clean_text(text):
    text = re.sub(r'\[.*?\]', '', text)  # Remove HTML-like tags [b], [i], etc.
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)  # Keeps letters, numbers, and spaces
    return text

# Updated preprocess_lemma function
def preprocess_lemma(text):
    """
    Preprocess text by:
       - Removing special characters, emojis, and HTML tags.
       - Lemmatizing the text using spaCy.
       - Keeping only alphabetic words (removes numbers & symbols).
    
    Returns:
        str: A string of lemmatized words separated by spaces.
    """
    # Load spaCy model
    nlp = spacy.load("en_core_web_sm")
    text = clean_text(text)  # Remove special characters
    doc = nlp(text)  # Process text with spaCy
    lemmatized_tokens = [token.lemma_ for token in doc if not token.is_stop and token.is_alpha]  # Keep only words
    return " ".join(lemmatized_tokens)

def tokenize(text, mode=0):
    """
    General tokenize function. Always applies punctuation and stopword removal and then:
    
      mode = 0: Applies lowercasing.
      mode = 1: Applies lowercasing and stemming.
      mode = 2: Applies lemmatization (without lowercasing the original text).
    
    Args:
        text (str): The input text to be processed.
        mode (int): Processing mode (0 for lowercasing; 1 for stemming; 2 for lemmatizing).

    Returns:
        str: A string of processed tokens separated by spaces.

    Raises:
        ValueError: If an invalid mode is provided.
    """
    if mode == 0:
        return preprocess_lower(text)
    elif mode == 1:
        return preprocess_stem(text)
    elif mode == 2:
        return preprocess_lemma(text)
    else:
        raise ValueError("Invalid mode. Please use 0 for lowercasing, 1 for stemming, or 2 for lemmatizing.")

# %%
#Getting the clean text column
mod=2 #Lemmatizing

# Pre-process the text column with progress tracking
try:
    user_reviews["cleaned_review"] = user_reviews["review"].progress_apply(lambda x: tokenize(str(x), mod))
    print("Done processing text.")
except Exception as e:
    print(f"Error processing text column: {e}")
    sys.exit(1)
# Out:
# 100%|██████████| 6/6 [00:01<00:00,  3.73it/s]
# Done processing text.

# %%
pos_reviews_cleaned = user_reviews[user_reviews["recommended"] == "True"].copy()
neg_reviews_cleaned = user_reviews[user_reviews["recommended"] == "False"].copy()
pos_reviews_cleaned = pos_reviews_cleaned.dropna(subset=['cleaned_review'])
pos_reviews_cleaned["cleaned_review"] = pos_reviews_cleaned["cleaned_review"].apply(remove_custom_stopwords)

# Remove NaN values and apply custom stopwords removal for negative reviews
neg_reviews_cleaned = neg_reviews_cleaned.dropna(subset=['cleaned_review'])
neg_reviews_cleaned["cleaned_review"] = neg_reviews_cleaned["cleaned_review"].apply(remove_custom_stopwords)

vectorizer_pos = TfidfVectorizer(stop_words="english", ngram_range=(1,2), max_features=5000)
vectorizer_neg = TfidfVectorizer(stop_words="english", ngram_range=(1,2), max_features=5000)

# Apply TF-IDF on positive reviews

user_pos_doc = " ".join(pos_reviews_cleaned["cleaned_review"])
tfidf_matrix_pos = vectorizer_pos.fit_transform([user_pos_doc])

terms_pos = vectorizer_pos.get_feature_names_out()

# Apply TF-IDF on negative reviews

user_neg_doc = " ".join(neg_reviews_cleaned["cleaned_review"])
tfidf_matrix_neg = vectorizer_neg.fit_transform([user_neg_doc])
# TF-IDF scores for one document
terms_pos = vectorizer_pos.get_feature_names_out()
tfidf_sum_pos = tfidf_matrix_pos.toarray()[0]

terms_neg = vectorizer_neg.get_feature_names_out()
tfidf_sum_neg = tfidf_matrix_neg.toarray()[0]

# Create the DataFrames
tfidf_df_pos = pd.DataFrame({'term': terms_pos, 'tfidf_score': tfidf_sum_pos}).sort_values(by="tfidf_score", ascending=False)
tfidf_df_neg = pd.DataFrame({'term': terms_neg, 'tfidf_score': tfidf_sum_neg}).sort_values(by="tfidf_score", ascending=False)

# Display the TF-IDF DataFrames
print("\nTop Positive User Profile TF-IDF Terms:\n", tfidf_df_pos.head(10))
print("\nTop Negative User Profile TF-IDF Terms:\n", tfidf_df_neg.head(10))
# Out:
# Top Positive User Profile TF-IDF Terms:
#               term  tfidf_score
# 57     experience     0.253490
# 122       require     0.190117
# 23         combat     0.190117
# 142         story     0.190117
# 166         world     0.190117
# 14   breathtaking     0.126745
# 146      strategy     0.126745
# 65          fight     0.126745
# 116         quest     0.126745
# 119    repetitive     0.126745
#
# Top Negative User Profile TF-IDF Terms:
#                     term  tfidf_score
# 114               story     0.224231
# 103          repetitive     0.149487
# 64                 lack     0.149487
# 39           experience     0.149487
# 85   overall experience     0.149487
# 84              overall     0.149487
# 28              defense     0.149487
# 115        story engage     0.149487
# 90               plenty     0.149487
# 33               engage     0.149487

# %% [markdown]
# Now that we have our user profile we can proceed with the recommendation system.

# %% [markdown]
# # Getting the Recommendations

# %% [markdown]
# Using Cosine Similarity we will determine which games will be good recommendations for the user. In the following lines you will find our initial approach and its results.

# %%
# Convert TF-IDF dataframes into dictionaries for fast lookup
user_pos_profile = dict(zip(tfidf_df_pos["term"], tfidf_df_pos["tfidf_score"]))
user_neg_profile = dict(zip(tfidf_df_neg["term"], tfidf_df_neg["tfidf_score"]))

from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Function to compute cosine similarity between two TF-IDF vectors
def compute_cosine_similarity(user_profile, game_profile):
    # Create aligned vectors (matching words in both profiles)
    all_terms = set(user_profile.keys()).union(set(game_profile.keys()))

    # Convert profiles into numerical vectors
    user_vector = np.array([user_profile.get(term, 0) for term in all_terms])
    game_vector = np.array([game_profile.get(term, 0) for term in all_terms])

    # Compute cosine similarity
    similarity = cosine_similarity([user_vector], [game_vector])[0][0]
    return similarity

# %%
game_similarity_scores = []
# Replace any NaNs in the word columns with empty lists
df_top_words["Top_Positive_Words"] = df_top_words["Top_Positive_Words"].apply(lambda x: x if isinstance(x, list) else [])
df_top_words["Top_Negative_Words"] = df_top_words["Top_Negative_Words"].apply(lambda x: x if isinstance(x, list) else [])

# Iterate through each game and compute similarity
for index, row in df_top_words.iterrows():
    game_name = row["Game"]

    # Convert game terms into dictionaries
    game_pos_profile = dict(zip(row["Top_Positive_Words"], [1]*len(row["Top_Positive_Words"])))
    game_neg_profile = dict(zip(row["Top_Negative_Words"], [1]*len(row["Top_Negative_Words"])))

    # Compute cosine similarity with user profile
    pos_sim = compute_cosine_similarity(user_pos_profile, game_pos_profile)
    neg_sim = compute_cosine_similarity(user_neg_profile, game_neg_profile)

    # Calculate final score (favor positive similarity, penalize negative similarity)
    final_score = pos_sim - neg_sim

    # Store results
    game_similarity_scores.append((game_name, pos_sim, neg_sim, final_score))

# Convert to DataFrame
df_game_recommendations = pd.DataFrame(game_similarity_scores, columns=["Game", "Positive_Similarity", "Negative_Similarity", "Final_Score"])

# Sort by final score
df_game_recommendations = df_game_recommendations.sort_values(by="Final_Score", ascending=False)

df_game_recommendations
# Out:
#                                 Game  Positive_Similarity  \
# 69             Red Dead Redemption 2             0.200401
# 51      Kingdom Come: Deliverance II             0.240481
# 71    Robin Hood - Sherwood Builders             0.160321
# 93  Warhammer 40,000: Space Marine 2             0.160321
# 8                       Atomic Heart             0.200401
# ..                               ...                  ...
# 90                       Tower Unite             0.000000
# 13                 Battlefield™ 2042             0.000000
# 3              ARK: Survival Evolved             0.000000
# 58             Monster Hunter: World             0.000000
# 87                             Thief             0.060120
#
#     Negative_Similarity  Final_Score
# 69             0.000000     0.200401
# 51             0.047272     0.193209
# 71             0.000000     0.160321
# 93             0.000000     0.160321
# 8              0.047272     0.153129
# ..                  ...          ...
# 90             0.023636    -0.023636
# 13             0.023636    -0.023636
# 3              0.023636    -0.023636
# 58             0.047272    -0.047272
# 87             0.118180    -0.058060
#
# [97 rows x 4 columns]

# %% [markdown]
# We can see how most of the recommended games make sense, but not all of them.
# What is very interesting is that we get some games recommended to which we made positive reviews.
# This makes sense but it should nevertheless not happen so we take it out of range of predictions:

# %%
# Remove games that the user has already reviewed from recommendations
df_filtered_recommendations = df_game_recommendations[~df_game_recommendations["Game"].isin(user_reviews["Game"])]

# Display the updated recommendations without already-reviewed games
df_filtered_recommendations.head(10)
# Out:
#                                 Game  Positive_Similarity  \
# 69             Red Dead Redemption 2             0.200401
# 51      Kingdom Come: Deliverance II             0.240481
# 71    Robin Hood - Sherwood Builders             0.160321
# 93  Warhammer 40,000: Space Marine 2             0.160321
# 8                       Atomic Heart             0.200401
# 44                         Fallout 4             0.160321
# 19                         CODE VEIN             0.120241
# 92                           Valheim             0.120241
# 53               MONSTER HUNTER RISE             0.120241
# 88                      Titanfall® 2             0.100201
#
#     Negative_Similarity  Final_Score
# 69             0.000000     0.200401
# 51             0.047272     0.193209
# 71             0.000000     0.160321
# 93             0.000000     0.160321
# 8              0.047272     0.153129
# 44             0.023636     0.136685
# 19             0.000000     0.120241
# 92             0.000000     0.120241
# 53             0.000000     0.120241
# 88             0.000000     0.100201

# %% [markdown]
# # Improving Predictions

# %% [markdown]
# To improve our predictions furthermore, we will include the genre booleans.
#
# Let's recap what dataframes we still have and can use for this process:

# %%
user_reviews.head() #Remember we still have our dataframe of user reviews, so let's use the extra features!
# Out:
#                        Game  \
# 0  The Witcher 3: Wild Hunt
# 1              Dark Souls 3
# 2          X-Morph: Defense
# 3            Cyberpunk 2077
# 4         Horizon Zero Dawn
#
#                                               review recommended  \
# 0  I really enjoyed The Witcher 3 because of its ...        True
# 1  Dark Souls 3 was an amazing experience. The qu...        True
# 2  I did not like X-Morph: Defense because it's a...       False
# 3  Cyberpunk 2077 had a lot of potential with its...       False
# 4  Horizon Zero Dawn was an incredible game with ...        True
#
#                      genre  action  strategy  free_to_play  adventure  \
# 0          RPG, Open World   False     False         False       True
# 1              Action, RPG    True     False         False      False
# 2  Strategy, Tower Defense   False      True         False      False
# 3  Action, RPG, Open World    True     False         False       True
# 4        Action, Adventure    True     False         False       True
#
#    massively_multiplayer  indie  ...  casual  racing  early_access  \
# 0                  False  False  ...   False   False         False
# 1                  False  False  ...   False   False         False
# 2                  False  False  ...   False   False         False
# 3                  False  False  ...   False   False         False
# 4                  False  False  ...   False   False         False
#
#    simulation  unknown_genre  sports  violent  education  utilities  \
# 0       False          False   False     True      False      False
# 1       False          False   False     True      False      False
# 2       False          False   False    False      False      False
# 3       False          False   False     True      False      False
# 4       False          False   False    False      False      False
#
#                                       cleaned_review
# 0  enjoy Witcher vast open world deep story breat...
# 1  Dark Souls amazing experience quest design int...
# 2  like XMorph Defense tower defense game m genre...
# 3  cyberpunk lot potential futuristic open world ...
# 4  Horizon Zero Dawn incredible game unique blend...
#
# [5 rows x 21 columns]

# %% [markdown]
# Let's create a feature profile.
#
# We simply calculate a score based on the average of each genre, effectively saying how much each genre matters for the gamer.

# %%
# Define lambda (weighting for feature matching)
lambda_weight = 0.5  # Adjust based on preference (higher = genre matters more)
user_reviews["recommended"] = user_reviews["recommended"].astype(bool)
# Compute the user's preferred feature profile
user_feature_profile = user_reviews[user_reviews["recommended"] == True].drop(
    columns=["Game", "review", "recommended", "genre", "cleaned_review"]
).mean() #we take the mean to normalize the sum

# %%
user_feature_profile
# Out:
# action                   0.666667
# strategy                 0.166667
# free_to_play             0.000000
# adventure                0.666667
# massively_multiplayer    0.000000
# indie                    0.000000
# rpg                      0.833333
# casual                   0.000000
# racing                   0.000000
# early_access             0.000000
# simulation               0.000000
# unknown_genre            0.000000
# sports                   0.000000
# violent                  0.666667
# education                0.000000
# utilities                0.000000
# dtype: float64

# %% [markdown]
# Seems like action, rpg, and adventure are the most important genres to him or her!
#
# To include this in our similarity score, we need the genre booleans in our recommendation dataframe as well. Remember that it just included Game, Similarity and Score?
# This is why we join it with the unique game_reviews below!

# %%
genre_columns = ["Game", "action", "strategy", "free_to_play", "adventure", 
                 "massively_multiplayer", "indie", "rpg", "casual", "racing", 
                 "early_access", "simulation", "unknown_genre", "sports", 
                 "violent", "education", "utilities"] #these are exactly the same as the ones in our dataframe of game_reviews

unique_game_features = game_reviews[genre_columns].drop_duplicates(subset=["Game"]) #We only need the infortmation of 1 review per game

# Merge df_filtered_recommendations with unique game metadata
df_filtered_recommendations = df_filtered_recommendations.merge(
    unique_game_features, on="Game", how="left"
)
#including all games:
df_game_recommendations = df_game_recommendations.merge(
    unique_game_features, on="Game", how="left"

)

# %%
df_filtered_recommendations.head()
# Out:
#                                Game  Positive_Similarity  Negative_Similarity  \
# 0             Red Dead Redemption 2             0.200401             0.000000
# 1      Kingdom Come: Deliverance II             0.240481             0.047272
# 2    Robin Hood - Sherwood Builders             0.160321             0.000000
# 3  Warhammer 40,000: Space Marine 2             0.160321             0.000000
# 4                      Atomic Heart             0.200401             0.047272
#
#    Final_Score  action  strategy  free_to_play  adventure  \
# 0     0.200401    True     False         False       True
# 1     0.193209    True     False         False       True
# 2     0.160321   False     False         False       True
# 3     0.160321    True     False         False       True
# 4     0.153129    True     False         False       True
#
#    massively_multiplayer  indie    rpg  casual  racing  early_access  \
# 0                  False  False  False   False   False         False
# 1                  False  False   True   False   False         False
# 2                  False   True   True   False   False         False
# 3                  False  False   True   False   False         False
# 4                  False  False   True   False   False         False
#
#    simulation  unknown_genre  sports  violent  education  utilities
# 0       False          False   False    False      False      False
# 1       False          False   False    False      False      False
# 2       False          False   False    False      False      False
# 3       False          False   False    False      False      False
# 4       False          False   False    False      False      False

# %%
df_game_recommendations.head() #We initially worked with df_filtered_recommendations, but we decided to not filter for performance evaluations as described above.
# Out:
#                                Game  Positive_Similarity  Negative_Similarity  \
# 0             Red Dead Redemption 2             0.200401             0.000000
# 1      Kingdom Come: Deliverance II             0.240481             0.047272
# 2    Robin Hood - Sherwood Builders             0.160321             0.000000
# 3  Warhammer 40,000: Space Marine 2             0.160321             0.000000
# 4                      Atomic Heart             0.200401             0.047272
#
#    Final_Score  action  strategy  free_to_play  adventure  \
# 0     0.200401    True     False         False       True
# 1     0.193209    True     False         False       True
# 2     0.160321   False     False         False       True
# 3     0.160321    True     False         False       True
# 4     0.153129    True     False         False       True
#
#    massively_multiplayer  indie    rpg  casual  racing  early_access  \
# 0                  False  False  False   False   False         False
# 1                  False  False   True   False   False         False
# 2                  False   True   True   False   False         False
# 3                  False  False   True   False   False         False
# 4                  False  False   True   False   False         False
#
#    simulation  unknown_genre  sports  violent  education  utilities
# 0       False          False   False    False      False      False
# 1       False          False   False    False      False      False
# 2       False          False   False    False      False      False
# 3       False          False   False    False      False      False
# 4       False          False   False    False      False      False

# %%
#df_filtered_recommendations=df_game_recommendations.copy() #however, we will work with df_game_recommendations without filters below!

# %% [markdown]
# ### Computing the Feature Score

# %% [markdown]
# To work with this, we will extract the booleans and convert into a numpy vector to work with it.

# %%
game_features_matrix = df_filtered_recommendations.drop(
    columns=["Game", "Positive_Similarity", "Negative_Similarity", "Final_Score"], errors="ignore"
).values

user_feature_vector = user_feature_profile.values

# %% [markdown]
# As we have a matrix and a vector and we want to compare the row (each game) with the vector of the user, we can compute the dot product. The dot product acts as a kind of similiarity measure (the higher the more similiar), so we can apply this and efficiently compute the final feature score!

# %%
genre_columns = list(user_feature_profile.index)  # we only have 16 genres in user column so we need to make it match the game genres (not needed in real life)

# Now select just those columns from the recommendations
game_features_matrix = df_filtered_recommendations[genre_columns].values
user_feature_vector = user_feature_profile.values

# Compute dot product
df_filtered_recommendations["Feature_Match_Score"] = np.dot(game_features_matrix, user_feature_vector)

# %% [markdown]
# Lastly, we put all three scores together: Positive Similiarity, Negative Similarity and Feature Match Score:
#
# This results into a **new Final_Score**, including not only the similarity from before but also the genre features!

# %%
df_filtered_recommendations["Final_Score"] = (
    df_filtered_recommendations["Positive_Similarity"] 
    - df_filtered_recommendations["Negative_Similarity"]
    + lambda_weight * df_filtered_recommendations["Feature_Match_Score"]  # we use the same lambda as before!
)

# Step 3: Sort and display new recommendations
df_filtered_recommendations = df_filtered_recommendations.sort_values(by="Final_Score", ascending=False)

df_filtered_recommendations.head(10)
# Out:
#                                 Game  Positive_Similarity  \
# 1       Kingdom Come: Deliverance II             0.240481
# 3   Warhammer 40,000: Space Marine 2             0.160321
# 4                       Atomic Heart             0.200401
# 7                            Valheim             0.120241
# 73                   Elite Dangerous             0.000000
# 22                           Exanima             0.060120
# 25         Assassin's Creed® Origins             0.120241
# 26                          Yakuza 0             0.140281
# 27                          Terraria             0.040080
# 37            ARK: Survival Ascended             0.040080
#
#     Negative_Similarity  Final_Score  action  strategy  free_to_play  \
# 1              0.047272     1.276543    True     False         False
# 3              0.000000     1.243654    True     False         False
# 4              0.047272     1.236463    True     False         False
# 7              0.000000     1.203574    True     False         False
# 73             0.000000     1.166667    True      True         False
# 22             0.000000     1.143454    True     False         False
# 25             0.070908     1.132666    True     False         False
# 26             0.094544     1.129070    True     False         False
# 27             0.000000     1.123414    True     False         False
# 37             0.023636     1.099778    True     False         False
#
#     adventure  massively_multiplayer  indie  ...  casual  racing  \
# 1        True                  False  False  ...   False   False
# 3        True                  False  False  ...   False   False
# 4        True                  False  False  ...   False   False
# 7        True                  False   True  ...   False   False
# 73       True                   True  False  ...   False   False
# 22       True                  False   True  ...   False   False
# 25       True                  False  False  ...   False   False
# 26       True                  False  False  ...   False   False
# 27       True                  False   True  ...   False   False
# 37       True                   True   True  ...   False   False
#
#     early_access  simulation  unknown_genre  sports  violent  education  \
# 1          False       False          False   False    False      False
# 3          False       False          False   False    False      False
# 4          False       False          False   False    False      False
# 7           True       False          False   False    False      False
# 73         False        True          False   False    False      False
# 22          True        True          False   False    False      False
# 25         False       False          False   False    False      False
# 26         False       False          False   False    False      False
# 27         False       False          False   False    False      False
# 37          True       False          False   False    False      False
#
#     utilities  Feature_Match_Score
# 1       False             2.166667
# 3       False             2.166667
# 4       False             2.166667
# 7       False             2.166667
# 73      False             2.333333
# 22      False             2.166667
# 25      False             2.166667
# 26      False             2.166667
# 27      False             2.166667
# 37      False             2.166667
#
# [10 rows x 21 columns]

# %% [markdown]
# We can see how our predictions changed quite a bit! This heavily depends on or weight parameter alpha. After playing around a bit, we decided that 0.5 would be a good fit however, since the results make a lot of sense with it. For example, the game "Kingdom Come" is still included in our final predictions, but we can see how some other games like  Elite Dangerous appeared quite high in the list, which did not appear in our original recommendations but do appear now!
#
# However, judging the performance for this system is the most challenging part of such game recommendation systems. So in general it is very difficult to say how well this system performs, but more on that can be read in the report.

# %% [markdown]
# ## Performance Evaluation

# %% [markdown]
# As described in the report, evaluating performance is not as straightforward as in ordinary ML algorithms but some usefull information will be plotted and described below.

# %% [markdown]
# ### Plots

# %% [markdown]
# In some way, we can check how our system performs by analyziing how strongly games in the final recommendations match the user’s profile. If scores are high, it indicates very close matches. if scores are low, it indicates that the model could maybe be improved.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Histogram of similarity scores in recommendations
plt.figure(figsize=(8, 5))
plt.hist(df_filtered_recommendations["Final_Score"], bins=20, alpha=0.7, color="blue", edgecolor="black")
plt.xlabel("Final Recommendation Score")
plt.ylabel("Number of Games")
plt.title("Distribution of Recommendation Scores")
plt.show()

# %%
from scipy.stats import spearmanr

# Compute correlation between user feature profile and recommended game features
feature_columns = ["action", "strategy", "free_to_play", "adventure", "massively_multiplayer",
                   "indie", "rpg", "casual", "racing", "early_access", "simulation",
                   "unknown_genre", "sports", "violent", "education", "utilities"]

# Compute Spearman rank correlation
correlations = {}
for feature in feature_columns:
    correlation, _ = spearmanr(df_filtered_recommendations[feature], df_filtered_recommendations["Final_Score"])
    correlations[feature] = correlation

# Sort by highest correlation
correlations = dict(sorted(correlations.items(), key=lambda x: abs(x[1]), reverse=True))

# Print correlations
print("Correlation between Features & Final Score:\n")
for feature, corr in correlations.items():
    print(f"{feature}: {corr:.3f}")
# Out:
# Correlation between Features & Final Score:
#
# adventure: 0.732
# rpg: 0.682
# action: 0.402
# massively_multiplayer: 0.284
# sports: -0.231
# education: -0.167
# utilities: -0.167
# strategy: -0.154
# unknown_genre: -0.149
# early_access: 0.144
# free_to_play: -0.136
# violent: 0.136
# simulation: -0.111
# racing: -0.106
# indie: 0.046
# casual: 0.012

# %%
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.kdeplot(df_filtered_recommendations["Positive_Similarity"], label="Positive Similarity", shade=True, color="green")
sns.kdeplot(df_filtered_recommendations["Negative_Similarity"], label="Negative Similarity", shade=True, color="red")
plt.xlabel("Similarity Score")
plt.ylabel("Density")
plt.title("Positive vs. Negative Similarity Distribution")
plt.legend()
plt.show()
# Out:
# /var/folders/qq/ny6dn2_d5wl2yjtn17gtz13r0000gn/T/ipykernel_13121/3242741047.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_filtered_recommendations["Positive_Similarity"], label="Positive Similarity", shade=True, color="green")
# /var/folders/qq/ny6dn2_d5wl2yjtn17gtz13r0000gn/T/ipykernel_13121/3242741047.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_filtered_recommendations["Negative_Similarity"], label="Negative Similarity", shade=True, color="red")

# %% [markdown]
# # Adaptive Feedback System

# %% [markdown]
# As the reviews are written by us and we can tell which games we like or equivalently which recommendations we like, we decide to "approve" / "like" the following recommendations:
#
# **"Kingdom Come: Deliverance II", "Elite Dangerous", "Crusader Kings III"**
#
# However, the recommendatino **"Rust"** does not seem very relevant to us, therefore we dislike it.
#
# This means we give these game a higher/lower weight in our feature mapping, adjusting the final score!

# %%
# Example: User liked "Kingdom Come, Elite Dangerous and Crusader Kings" but disliked "Rust"
liked_games = ["Kingdom Come: Deliverance II", "Elite Dangerous", "Crusader Kings III"]
disliked_games = ["Rust"]

# Adjust the user feature profile
for game in liked_games:
    game_features = df_filtered_recommendations[df_filtered_recommendations["Game"] == game][user_feature_profile.index]
    user_feature_profile += game_features.mean() * 0.1  # Increase weight for liked game features

for game in disliked_games:
    game_features = df_filtered_recommendations[df_filtered_recommendations["Game"] == game][user_feature_profile.index]
    user_feature_profile -= game_features.mean()

# %% [markdown]
# After this, we have to recompute everything again.

# %% [markdown]
# #### Recomputations

# %%
# Recompute TF-IDF profiles after user feedback
user_pos_profile = dict(zip(tfidf_df_pos["term"], tfidf_df_pos["tfidf_score"]))
user_neg_profile = dict(zip(tfidf_df_neg["term"], tfidf_df_neg["tfidf_score"]))

game_similarity_scores = []
for index, row in df_top_words.iterrows():
    game_name = row["Game"]
    
    game_pos_profile = dict(zip(row["Top_Positive_Words"], [1]*len(row["Top_Positive_Words"])))
    game_neg_profile = dict(zip(row["Top_Negative_Words"], [1]*len(row["Top_Negative_Words"])))

    pos_sim = compute_cosine_similarity(user_pos_profile, game_pos_profile)
    neg_sim = compute_cosine_similarity(user_neg_profile, game_neg_profile)

    final_score = pos_sim - neg_sim

    game_similarity_scores.append((game_name, pos_sim, neg_sim, final_score))

df_game_recommendations = pd.DataFrame(
    game_similarity_scores, 
    columns=["Game", "Positive_Similarity", "Negative_Similarity", "Final_Score"]
)

df_game_recommendations = df_game_recommendations.sort_values(by="Final_Score", ascending=False)


df_game_recommendations = df_game_recommendations.merge(
    unique_game_features, on="Game", how="left"
)

game_features_matrix = df_game_recommendations.drop(
    columns=["Game", "Positive_Similarity", "Negative_Similarity", "Final_Score"], errors="ignore"
).values

df_game_recommendations["Feature_Match_Score"] = np.dot(game_features_matrix, user_feature_profile)

df_game_recommendations["Final_Score"] = (
    df_game_recommendations["Positive_Similarity"] 
    - df_game_recommendations["Negative_Similarity"]
    + lambda_weight * df_game_recommendations["Feature_Match_Score"]
)

df_game_recommendations = df_game_recommendations.sort_values(by="Final_Score", ascending=False)

# Remove games that the user has already reviewed from recommendations
df_filtered_recommendations = df_game_recommendations[~df_game_recommendations["Game"].isin(user_reviews["Game"])]

df_filtered_recommendations
# Out:
#                                       Game  Positive_Similarity  \
# 38                      Crusader Kings III             0.040080
# 41                   Europa Universalis IV             0.040080
# 20                         Baldur's Gate 3             0.120241
# 30  Age of Empires IV: Anniversary Edition             0.040080
# 6                                Fallout 4             0.160321
# ..                                     ...                  ...
# 59                        The Survivalists             0.000000
# 39                  ARK: Survival Ascended             0.040080
# 55                                    Rust             0.000000
# 94                   ARK: Survival Evolved             0.000000
# 92                             Tower Unite             0.000000
#
#     Negative_Similarity  Final_Score  action  strategy  free_to_play  \
# 38             0.023636     0.366444   False      True         False
# 41             0.023636     0.299778   False      True         False
# 20             0.047272     0.256302   False      True         False
# 30             0.000000     0.223414   False      True         False
# 6              0.023636     0.203352   False     False         False
# ..                  ...          ...     ...       ...           ...
# 59             0.000000    -0.633333    True     False         False
# 39             0.023636    -1.000222    True     False         False
# 55             0.000000    -1.016667    True     False         False
# 94             0.023636    -1.040303    True     False         False
# 92             0.023636    -1.106969    True     False         False
#
#     adventure  massively_multiplayer  indie  ...  casual  racing  \
# 38      False                  False  False  ...   False   False
# 41      False                  False  False  ...   False   False
# 20       True                  False  False  ...   False   False
# 30      False                  False  False  ...   False   False
# 6       False                  False  False  ...   False   False
# ..        ...                    ...    ...  ...     ...     ...
# 59       True                  False   True  ...    True   False
# 39       True                   True   True  ...   False   False
# 55       True                   True   True  ...   False   False
# 94       True                   True   True  ...   False   False
# 92       True                   True   True  ...    True    True
#
#     early_access  simulation  unknown_genre  sports  violent  education  \
# 38         False        True          False   False    False      False
# 41         False        True          False   False    False      False
# 20         False       False          False   False    False      False
# 30         False       False          False   False    False      False
# 6          False       False          False   False    False      False
# ..           ...         ...            ...     ...      ...        ...
# 59         False       False          False   False    False      False
# 39          True       False          False   False    False      False
# 55         False       False          False   False    False      False
# 94         False       False          False   False    False      False
# 92          True       False          False   False    False      False
#
#     utilities  Feature_Match_Score
# 38      False             0.700000
# 41      False             0.566667
# 20      False             0.366667
# 30      False             0.366667
# 6       False             0.133333
# ..        ...                  ...
# 59      False            -1.266667
# 39      False            -2.033333
# 55      False            -2.033333
# 94      False            -2.033333
# 92      False            -2.166667
#
# [94 rows x 21 columns]

# %% [markdown]
# As we can see, our system succesfully changed and adapted to our Likings: "Crusader Kings III" is now top 1.
# Also notice how the other entries changed, since everything changes that involves the same genres. This is important to notice since this is what we care about. Most of the recommended games change, just because of this small update!
